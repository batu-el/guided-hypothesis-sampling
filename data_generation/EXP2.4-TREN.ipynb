# %%
### EXP2.4: TR -> EN

# %%
### Install Required Packages
# !pip install jsonlines sentencepiece # nltk evaluate unbabel-comet accelerate
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.1.0)
# Installing collected packages: sentencepiece, jsonlines
# Successfully installed jsonlines-4.0.0 sentencepiece-0.1.99

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
drive_PATH = '../content/drive/MyDrive/Colab Notebooks/l101.experiments.1'
# Out:
# Mounted at /content/drive

# %%
# General
import numpy as np
import tqdm
import random

# Data
import jsonlines
import torch

# Model
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M") # Load Model
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M") # Load Tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# M2M100ForConditionalGeneration(
#   (model): M2M100Model(
#     (shared): Embedding(128112, 1024, padding_idx=1)
#     (encoder): M2M100Encoder(
#       (embed_tokens): Embedding(128112, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100EncoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): M2M100Decoder(
#       (embed_tokens): Embedding(128112, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100DecoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=128112, bias=False)
# )

# %%
### Dataset
test_tr_PATH = drive_PATH + '/data/datasets/test_tr_1000.jsonl'
test_de_PATH = drive_PATH + '/data/datasets/test_de_1000.jsonl'
test_tr = []
test_de = []

with jsonlines.open(test_tr_PATH) as f:
    for line in f.iter():
        test_tr.append(line)
# with jsonlines.open(test_de_PATH) as f:
#     for line in f.iter():
#         test_de.append(line)

# %%
# SRC: TR
# TGT: EN
src_lang = "tr"
tgt_lang = "en"

# %%
### Setting the Language Configurations
dataset = test_tr
tokenizer.src_lang = src_lang
print(len(dataset))
# Out:
# 1000

# %%
### Decoding: Epsilon Sampling

res = []
temperature = 1
epsilon_cutoff = 0.02
num_candidates = 128

for sent in tqdm.tqdm(dataset):
  #print(sent['en'])
  src_sent = sent[src_lang]
  encoded_src_sent = tokenizer(src_sent, return_tensors="pt").input_ids.to("cuda")

  candidates = []
  for idxc in range(num_candidates):
    tgt_tokens = model.generate(encoded_src_sent, forced_bos_token_id=tokenizer.get_lang_id(tgt_lang), do_sample=True, temperature=temperature, epsilon_cutoff=0.02, num_beams=1, early_stopping=False, num_return_sequences=1)
    tgt_sent = tokenizer.batch_decode(tgt_tokens, skip_special_tokens=True)
    candidates.append(tgt_sent)

  res_sent = {'src': sent[src_lang], 'candidates': candidates, 'ref':sent[tgt_lang]}
  res.append(res_sent)

cand_de_PATH = drive_PATH+ f'/exp2.4.tren-n{num_candidates}-t{temperature}-e{epsilon_cutoff}.jsonl'
with jsonlines.open(cand_de_PATH, mode='w') as writer:
    for item in res:
        writer.write(item)
# Out:
# 100%|██████████| 1000/1000 [15:28:31<00:00, 55.71s/it]

# %%
res
# Out:
# [{'src': 'Bir federal yüksek mahkemesinde kendi önceki pozisyonuna karşı açılan hukuki itiraz konusundan hiç bahsetmedi.',
#   'candidates': [['He has never been discussing the issue of the legal objection against his previous position in a federal high court.'],
#    ['He never spoke of a legal objection against his previous position in a federal court.'],
#    ['A federal high court did not mention the matter of the legal objection opposed to its former position.'],
#    ['He was never mentioned a legal objection on his previous position at a federal high court.'],
#    ['He never mentioned the subject of legal objections against his previous post in a federal High Court.'],
#    ['He had never mentioned any legal objection against his previous position in a Federal Supreme Court.'],
#    ['He has never spoke of a legal objection to his previous position at a federal high court.'],
#    ['He never mentioned a legal objection on his prior post in a federal high court.'],
#    ['He has not spoken at the Federal Supreme Court about a legal appeal against his previous position.'],
#    ['He did not say about a legal objection against his previous post at a federal high court.'],
#    ['He has never stated the legal objections against his previous position at the Federal High Court.'],
#    ['He never said any legal objection against his earlier position in a federal high court.'],
#    ['He has never been told in a federal court about any legal objection against his previous position.'],
#    ['He had never discussed a legal dispute to its previous position in a federal high court.'],
#    ['He has never spoke of a legal objection on its previous position at the federal High Court.'],
#    ['He hadn’t ever talked in a federal high court on the legal dispute against his previous position.'],
#    ['He had never discussed any lawful objection against his previous position in a federal high court.'],
#    ['He has never mentioned the subject of a legal objection against his previous position in a federal high court.'],
#    ['He has never mentioned a lawful objection on a federal high Court that appeals to his previous position.'],
#    ['He has never mentioned the legal object against his previous post by a federal court.'],
#    ["He hadn't discussed a top federal court of any legal dispute against his previous position."],
#    ['He never spoke of an legal objection against his previous position in a federal high court.'],
#    ['He never spoke of a lawsuit on his former post on a federal high court.'],
#    ['He had never stated the issue of a lawful appeal on his previous position in a Federal High Court.'],
#    ['He did not talk about the legal objection that was made against his previous position in a federal court.'],
#    ['He has not ever spoken about a legal objection against his previous post in a federal high court.'],
#    ['He did not speak at any federal court of any of the legal objections against his previous position.'],
#    ['He never spoke of the issue of a legal objection on his previous position at a federal Supreme Court.'],
#    ['He never talked to the top federal court about the legal proceedings opened against his previous position.'],
#    ['He has never discussed a legal objection against his previous position at a federal court.'],
#    ['He did not speak at any federal court on the subject of legal proceedings which was opened against his previous position.'],
#    ['He was never spoke of any legal objection against his previous position in a federal court.'],
#    ['He has never mentioned the legal dispute on his previous position at a federal high court.'],
#    ['He never spoke on a lawsuit against his previous position in a federal high court.'],
#    ['In a federal high court he has not mentioned any legal appeal against his previous position.'],
#    ['He never mentioned a legal objection against the previous position at a federal high court.'],
#    ['He has never discussed a legal object against his previous position at the high federal court.'],
#    ['He did not speak in a federal high court about a legal appeal against his former position.'],
#    ['She never mentioned a legal objection against his previous post at a Federal Supreme Court.'],
#    ["He hasn't ever mentioned the legal objection to his earlier position in a federal High Court."],
#    ['He has never stated the subject of a legal objection against his previous position at a federal High Court.'],
#    ['He did not mention the legal objection against his previous position in a Federal High Court.'],
#    ['He did not mention any law in the federal higher court which appealed against his previous position.'],
#    ['He never mentioned the legal object of his previous position in the federal court.'],
#    ['He has never mentioned a lawsuite objection against his previous position at a federal high court.'],
#    ['He never mentioned an opposition against his previous position at a federal high court.'],
#    ['He has never stated the legal object that was opened against his previous post in a federal Supreme Court.'],
#    ['He has never spoken about a legal objective against his former position in a federal high court.'],
#    ['He did not mention the case of legal appeal against his previous position in a federal high court.'],
#    ['He has never mentioned a matter of legal objection against his previous position at a Federal High Court.'],
#    ['He has never mentioned the legal object against his previous position at a federal Supreme Court.'],
#    ["He hasn't mentioned any legal objection against his previous position in a federal High Court at all."],
#    ["He hasn't spoken on a federal court on a legal objects against his previous position."],
#    ['He has never mentioned an opposition in an federal high court on the question opposed to his earlier position.'],
#    ['He has never said of a legal objection opened against his prior position in the federal high court.'],
#    ['He has not spoken for the legal action against his previous position by a federal Supreme Court.'],
#    ['A federal high court has never talked about the issue of legal objection against his previous position.'],
#    ['He was never mentioned on a federal high court the issue of the lawful objective against his previous position.'],
#    ['He was no one who discussed the case of legal objections against his previous post at a federal court.'],
#    ['He had no mention on the legal contest against his former post at a federal high court.'],
#    ['He had not yet stated about the legal objection opposed to his previous position at a Federal High Court.'],
#    ['He did not discuss the issue of legal appeal against his previous position in a federal High Court at all.'],
#    ['He has never mentioned any legal objections that appeared against his prior position at the Federal Supreme Court.'],
#    ['He has not mentioned any legal objection to his previous post at a federal court.'],
#    ['He has never mentioned an appeal on the issue that was made against his previous position at a federal high court.'],
#    ['He never discussed a legal objection that was brought against his previous position in a federal high court.'],
#    ['He never discussed the question of a legal objection against his previous position at a federal higher court.'],
#    ['He has never spoke about legal objection against his previous position at the Supreme Court.'],
#    ['He has never stated any lawful objection against his previous position by a federal Supreme Court.'],
#    ['He did not speak of a lawful complaint that was opened against his previous position at a Federal Court.'],
#    ['He had never discussed a legal objection against his previous post in a federal Supreme Court.'],
#    ['He never stated any lawsuit against the Federal Supreme Court against his previous post.'],
#    ['He has never been spoke about a legal objection against his previous position in the federal high court.'],
#    ['He had never mentioned the case of an appeal against his previous position in a Federal High Court.'],
#    ['He has never discussed the legal appeal against his previous position in a federal high Court.'],
#    ['He has never spoken on the issue of the legal objection against his earlier position at a federal high court.'],
#    ['He never said of the legal objection to his previous position in a federal high court.'],
#    ['He had never mentioned the question of a legal objection against his earlier position at a federal high court.'],
#    ['He never talked about the legal object that appealed against his previous position at a federal high court.'],
#    ['He has never stated about the legal objection against his previous position in a federal high court.'],
#    ['He never spoke about the case against his previous position in a federal high court.'],
#    ['She had never been spoken in a federal high court on a legal objection against her previous position.'],
#    ['He never mentioned a law in a federal High Court on the issue against his previous position.'],
#    ["He hadn't mentioned any legal objection to his previous position in a federal High Court."],
#    ['He has never mentioned a matter of legal objection against his previous position in a federal High Court.'],
#    ['He never discussed a legal objection to his former position at a federal court in his top.'],
#    ['He did not speak any of the legal objections opened against the previous position at a federal Supreme Court.'],
#    ['He has never said the matter of a lawful appeal against his previous post in a federal high court.'],
#    ['He did not mention any legal appeal that had been opened against his previous position in a federal high court.'],
#    ['He had never mentioned in a federal High Court a legal objection on his earlier position.'],
#    ['He never mentioned an act in a federal high court against his earlier position.'],
#    ['He has never mentioned the legal appeal to his previous position in the federal High Court.'],
#    ['He has never mentioned a lawsuite object against his previous position in a federal high court.'],
#    ['He has never said the matter of legal objection against the previous position at a federal High Court.'],
#    ['He did not speak at any federal high court of the issue of legal objection against his previous position.'],
#    ['He has not mentioned the matter of legal objection to his previous position in a federal High Court at all.'],
#    ['He has never said anything about the legal objection against his previous position at a federal high court.'],
#    ['He had never talked about a legal object in a federal high court against his previous position.'],
#    ['He has never mentioned in a federal high court a legal objection against his previous position.'],
#    ['He has never spoken about a lawful objection on his previous position at a federal high court.'],
#    ['He was never referred to the court of the High Court of the Federal Federation for any legal objection against his previous post.'],
#    ['He never discussed a legal appeal against his earlier position at a Federal Court.'],
#    ['He has never mentioned an appeal against his previous position in a federal court.'],
#    ['He did not speak of any legal complaint against his earlier position in a federal court.'],
#    ['He was never referring to a legal object against his earlier position at the federal high court.'],
#    ['He has not stated any appeal against the Federal Supreme Court against the previous position.'],
#    ['He has never stated the matter of the legal appeal on his previous position at an federal high court.'],
#    ['He has never mentioned an appeal against his previous position in a federal court.'],
#    ['He has never spoke of a legal objection to his previous position in the federal high court.'],
#    ['He had no reference to a legal objective brought on against the previous position at a federal high court.'],
#    ['A federal court had never spoke about a legal object against its previous position.'],
#    ['He has never stated a legal objection against his previous position at a federal court.'],
#    ['He has never spoken for a legal objection to his earlier position in a federal higher tribunal.'],
#    ['He has never discussed a legal objective against his previous position at a federal court.'],
#    ['He has never mentioned the legal objections opened against his previous position in a federal court in a Federal Court of Justice.'],
#    ['He has never discussed the legal appeal that he opened against his previous position at a federal Supreme Court.'],
#    ['A federal High Court has never mentioned the case of legal appeal to his previous position.'],
#    ['In a federal court he never mentioned the subject of legal objection against his previous position.'],
#    ['He has never spoke of any legal objection against his previous position at the Federal Supreme Court.'],
#    ['He never spoke about his legal appeal against his previous position in a federal court.'],
#    ['He never spoke about the case of legal objection against his previous position in a federal Supreme Court.'],
#    ['He has never mentioned the legal appeal against his previous position in a federal high court.'],
#    ['He has not spoken at a federal court on the legal appeal against his previous post.'],
#    ["He hasn't spoken about his case with the federal Supreme Court, which is opposed to his previous position."],
#    ['He has never been told in a federal court of appeal against his previous position.'],
#    ['He was never discussed against a legal objection on a federal high court in response to his previous position.'],
#    ['He has never mentioned any legal objections opened against his previous position at a Federal Supreme Court.'],
#    ['He was never spotted against a legal object against his previous position in a federal higher court.']],
#   'ref': 'He made no mention of the legal challenge filed against his prior position in a federal appeals court.'},
#  {'src': 'Temmuzda, kurumun Moskova\'daki genel merkezine yapılan bir ziyaretin ardından WADA Direktörü Olivier Niggli RUSADA\'nın yeniden işler hale gelmek için "doğru yönde ilerlediğini" açıklamıştı.',
#   'candidates': [['In July, following the visit to the institution’s headquarters in Moscow, the WADA Director, Olivier Niggli, stated that RUSADA ‘goed in the right direction’ to regain work.'],
#    ['After a visit to the agency’s headquarters in Moscow in July, WADA’s Director Olivier Niggli RUSADA had stated that they are going “in the right way” to make things back.'],
#    ["In July, after a visit to the Agency's headquarters in Moscow, WADA Director Olivier Niggli declared that the “proceedings in the right direction” are in an end to get the business again."],
#    ['After a visit to the institution\'s headquarters in Moscow in July, WADA Director Oliver Niggli declared RUSADA is "going in the right direction" in order to get business rebuilds.'],
#    ['In July, after a visit to the institution\'s headquarters in Moscow, WADA Director Olivier Niggli declared RUSADA\'s "progress in the correct direction" to turn into things again.'],
#    ['After a visit to the organization’s headquarters in Moscow on July, the WADA Director Olivier Niggli said RUSADA is “being in the right direction” in order to get the process again.'],
#    ['After a visit to the agency’s headquarters in Moscow in July, WADA Director Olivier Niggli said the agency was “going on the right track to regain” the work.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, the WADA Director Olivier Niggli RUSADA announced that "the good direction" is moving towards becoming the business back.'],
#    ['In July after an interview to the headquarters in Moscow, WADA Director Olivier Niggli RUSADA had stated that he was "going on the right way" to return to work.'],
#    ["In July, after a visit to the institutions' headquarters in Moscow, WADA’s director Olivier Niggli announced RUSADA is “being forward in the right direction to get things back.”"],
#    ['After an interview in July, the head of the organization at Moscow announced that WADA Director Olivier Niggli RUSADA was "receiting the right direction" to get things up.'],
#    ['In July, after a visit to the organization’s head office in Moscow, WADA Director Olivier Niggli RUSADA said that he was moving in the right direction to re-work.'],
#    ['On July, after a visit to the organization’s headquarters in Moscow, WADA’s Director Olivier Niggli RUSADA stated that it had “going forward in the right direction to be the job again.'],
#    ['In July, after a visit to the agency’s main office in Moscow, WADA director Olivier Niggli said RUSADA’s “going the right direction” to turn to work back.'],
#    ['After a visit to the agency’s headquarters in Moscow in July, WADA Director Olivier Niggli declared that RUSADA’s “going on the right direction” to resume the work.'],
#    ['After a visit to the foundation’s headquarters in Moscow in July, WADA Director Olivier Niggli said RUSADA’s “being moving in the right direction to get things up”.'],
#    ['In July, after a visit to the headquarters at Moscow, WADA Director Olivier Niggli said that RUSADA "haves moved in the right direction for the re-operation".'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA Director Olivier Niggli declared RUSADA’s “being forward in the right way to turn the business back.”'],
#    ['After a visit to the organization’s headquarters in Moscow in July, WADA Director Olivier Niggli declared that the RUSADA “going in the right way to get things back.”'],
#    ['In July, after a visit to the organization’s main site in Moscow, WADA director Olivier Niggli said the RUSADA was “going forward in the right direction to recover to work”.'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA was going “in the right direction” to get things back to the work.'],
#    ['In July, following a visit to the institution’s headquarters in Moscow, WADA director Olivier Niggli said that RUSADA had “goed right in the right direction” to make business again.'],
#    ['In July, following a visit to the institution’s headquarters in Moscow, the WADA Director Olivier Niggli announced RUSADA has “beaten in the right direction” to make things happen again.'],
#    ['After a visit to the Agency\'s headquarters in Moscow on July, WADA director Olivier Niggli said RUSADA was "going the right direction" to make it re-work.'],
#    ['In July, after a visit to the headquarters of the institution in Moscow, WADA Director Olivier Niggli RUSADA said he was moving "in the right direction" to return to the business.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, WADA Director Olivier Niggli RUSADA declared that he is "going forward in the right direction" in order to become things.'],
#    ['In July after a visit to the agency’s headquarters in Moscow, WADA director Olivier Niggli RUSADA said the company had “found the right direction” to turn back into work.'],
#    ['In July, following a visit to the Agency\'s headquarters in Moscow, WADA Director Olivier Niggli RUSADA said the "right way" is going towards becoming the work again.'],
#    ['In July, after a visit to the body’s headquarters in Moscow, WADA Director Olivier Niggli declared that RUSADA’s “going forward in the right direction” to be a return to business.'],
#    ['In July, following a visit to the institutions\' headquarters in Moscow, the WADA Director Olivier Niggli said RUSADA "going on the right way to become things again".'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA director Olivier Niggli RUSADA announced that it was “going forward” in a way to re-working.'],
#    ['After a visit to the institution’s central centre in Moscow, in July, WADA director Olivier Niggli said RUSADA was “going in the right direction to turn things back.”'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA Director Olivier Niggli said RUSADA’s “being going in the right direction” to make things go again.'],
#    ['Following an interview to the headquarters of the organization in Moscow in July, WADA director Olivier Niggli, RUSADA declared that he had been "founding in the right direction" to re-operation.'],
#    ['In July, following a visit to the organization’s headquarters in Moscow, WADA Director Olivier Niggli RUSADA that he is “proving the right direction to recover into work.”'],
#    ['In July, following a visit to the agency’s headquarters in Moscow, WADA Director Olivier Niggli declared RUSADA is “progressing in the right way to turn the things back in”.'],
#    ['In July, after a visit to the organization’s headquarters in Moscow, the WADA Director Olivier Niggli RUSADA declared that the “reason to work is going on to be backward.”'],
#    ['In July, following an visit to the agency\'s headquarters in Moscow, WADA director Olivier Niggli RUSADA said that he "goes in the right direction" to get things back.'],
#    ['In July, following a visit to the agency’s headquarters in Moscow, the WADA Director Olivier Niggli RUSADA declared that it “gos in the right direction” to make the work back.'],
#    ['In July, following a visit to the foundation’s headquarters in Moscow, WADA’s director Olivier Niggli RUSADA said he was “being going in the right way” to return to business.'],
#    ['On a visit to the agency’s headquarters in Moscow in July, WADA Director Oliver Niggli RUSADA announced that he “founded in the right direction” to become a re-work.'],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA was “going the right direction” to get things to return.'],
#    ['Following a visit to the institution’s headquarters in Moscow on July, WADA Director Olivier Niggli RUSADA had announced that he was ‘going in the right direction to recall the job’ in order to turn into work again.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, WADA Director Olivier Niggli RUSADA said he was "fighting in the right direction to make the business a re-work".'],
#    ['In July, after a visit to the organization\'s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA "goed the right direction" in order to make business recovery.'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, the WADA Director Olivier Niggli announced the RUSADA’s “going on the right direction” to recover to work.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, WADA Director Olivier Niggli declared that RUSADA has "going in the right direction" to recovery of things.'],
#    ['In July, following a visit to the organization\'s headquarters in Moscow, WADA Director Olivier Niggli said that the RUSADA has "goed rightward" to turn business back into the way.'],
#    ['In July, after an appointment to the agency’s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA “going forward in the right direction” to rework.'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, the WADA director Olivier Niggli declared that RUSADA “folded in the right direction” to re-operate.'],
#    ['In July, after a visit to the headquarters in Moscow, the WADA Director Olivier Niggli RUSADAly said he was “going in the right direction” to reverse the work.'],
#    ['After a visit to the institution’s headquarters in Moscow in July, WADA Director Olivier Niggli RUSADA announced that “the right direction is to re-work.”'],
#    ["On the occasion of a visit to the agency's headquarters in Moscow in July, WADA Director Olivier Niggli said RUSADA has been “founding the right direction to turn the work on a new place.”"],
#    ['In July, after a visit to the institution\'s headquarters in Moscow, WADA director Olivier Niggli said RUSADA is "being on the right way to turn things to return".'],
#    ['In July, after a visit to the organization’s headquarters in Moscow, WADA Director Olivier Niggli RUSADA that “their steps are going “in the right direction” to re-work.'],
#    ["After a visit to the agency's headquarters in Moscow in July, WADA Director Olivier Niggli RUSADA declared that he's “going forward in the right direction to make things work again.”"],
#    ['In July, after a visit to the organization’s headquarters in Moscow, WADA Director Olivier Niggli declared that RUSADA has “goed in the right direction” to make things re-work.'],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA director Olivier Niggli RUSADA said he had “been forward in the right direction to re-work.'],
#    ['After a visit to the body\'s headquarters in Moscow in July, the WADA director Olivier Niggli RUSADA told the report that he was "processing the right direction for the work to return to the work."'],
#    ['In July, following a visit to the Agency\'s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA was moving "in the right direction" to be doing things again.'],
#    ['Following a visit to the agency\'s headquarters in Moscow in July, WADA Director Olivier Niggli announced that the RUSADA has "found in the right direction" to re-operate.'],
#    ['In July, after a visit to the organization’s headquarters in Moscow, WADA Director Olivier Niggli said RUSADA had “goed in the right direction to re-operate.”'],
#    ['In July, following a visit to the body’s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA was “founding in the right direction” to turn things out again.'],
#    ['In July, after a visit to the institute’s headquarters in Moscow, WADA director Olivier Niggli RUSADA said that he “folds in the right direction” to re-work.'],
#    ['After a visit to the agency\'s headquarters in Moscow in July, the WADA Director Olivier Niggli RUSADA said that it has "going right towards to become jobs again".'],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA Director Oliver Niggli said that the RUSADA “proceeded in the right direction to become things again.”'],
#    ['On June, following a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli told Russia that it is ‘throing the right direction to go back into things’.'],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli said RUSADA is “going the right direction” to re-act to the things.'],
#    ['In July, following a visit to the agency\'s central center in Moscow, WADA Director Olivier Niggli RUSADA declared that he is "throuting on the right direction" to re-work.'],
#    ['On a visit to the headquarters in Moscow in July, the WADA Director Olivier Niggli declared the RUSADA\'s "going in the right direction to turn the things back".'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA Director Olivier Niggli declared that RUSADA “goes in the right direction to get back.”'],
#    ["After a visit to the agency's headquarters in Moscow in July, the WADA director Olivier Niggli told RUSADA to “go on the right direction to make things happen again.”"],
#    ["In July, after a visit to the agency's headquarters in Moscow, WADA Director Olivier Niggli RUSADA announced that the “Returns in the Right Way” is to re-work."],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli RUSADA announced that he was "bearing the right direction to resume things".'],
#    ['In July, following a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli has announced RUSADA’s “progressing the right way” to recall his business.'],
#    ['After a visit to the agency’s headquarters in Moscow in July, WADA’s Director Oliver Niggli said RUSADA has been “going in the right direction” to return.'],
#    ['In July, after a visit to the institution\'s central in Moscow, WADA Director Olivier Niggli said the RUSADA was "going in the right direction" to get things back.'],
#    ['In July, after an visit to the agency’s central in Moscow, WADA Director Olivier Niggli declared RUSADA was “being going to the right direction” to re-operate.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, the WADA Director Olivier Niggli RUSADA announced that he had "going in the right direction" to turn his job on again.'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA director Olivier Niggli said RUSADA was “going in the right way” to go back into work.'],
#    ['After a visit to the agency\'s central in Moscow in July, WADA Director Olivier Niggli declared RUSADA is "going the right direction" to become a new deal.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, WADA Director Olivier Niggli RUSADA said he was "going forward" in order to turn things back.'],
#    ['After a visit to the agency\'s headquarters in Moscow in July, the WADA Director, Olivier Niggli, told RUSADA that it was "progressing in the right direction" in order to recover the jobs.'],
#    ['After a visit to the organization’s headquarters in Moscow in July, WADA director Olivier Niggli said the company’s business was “receeding in the right direction” to be a re-operation.'],
#    ['In July, after a visit to the headquarters in Moscow, WADA Director Olivier Niggli RUSADA said he was “reaching the right direction” to turn the business back into the work.'],
#    ['After a visit to the agency’s headquarters in Moscow in July, WADA’s Director Olivier Niggli announced that RUSADA had “goed right in the way” to turn it into the reoperations.'],
#    ['In July, after a visit to the institute’s headquarters in Moscow, WADA Director Olivier Niggli announced the “righteous way” to re-work.'],
#    ['In July, after a visit to the institution\'s headquarters in Moscow, WADA director Olivier Niggli RUSADA told the public that he is "going in the right direction to get the new business."'],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA director Olivier Niggli announced that RUSADA was “reported to the right direction to re-operate.'],
#    ['In July, after a visit to the agency\'s head office in Moscow, WADA Director Olivier Niggli RUSADA stated that he\'s "progressing right in the way to get things back."'],
#    ["After a visit to the agency's headquarters in Moscow in July, the WADA Director Olivier Niggli declared RUSADA 'going in the right direction' to become the job."],
#    ["In July, following a visit to the agency's headquarters in Moscow, WADA Director Olivier Niggli said RUSADA is “going forward to the right direction” to make business up again."],
#    ['In July after a visit to the foundation’s Moscow headquarters, WADA Director Olivier Niggli said RUSADA’s progress was “in the right direction” to re-work.'],
#    ['In July, after a visit to the institute\'s headquarters in Moscow, WADA Director Olivier Niggli said that the RUSADA "going on the right direction" to be back.'],
#    ['In July, after a visit to the organization’s headquarters in Moscow, WADA director Olivier Niggli said RUSADA is “going on the right direction to reverse the business”.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, WADA Director Olivier Niggli RUSADA declared that it\'s "going to the right path" in order to re-work things.'],
#    ['After a visit to the agency’s headquarters in Moscow in July, WADA’s director Olivier Niggli RUSADA had stated that he has been “throuting in the right direction” to make things back into life.'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA Director Olivier Niggli declared RUSADA’s “going forward in the right direction” to return to business.'],
#    ['In July, following a visit to the agency\'s main hub in Moscow, the WADA Director Olivier Niggli RUSADA declared that they are "going in the right direction" to turn the business back.'],
#    ['Following a visit to the institution\'s headquarters in Moscow in July, the WADA Director Olivier Niggli said the RUSADA was "passing in the right direction" to be a re-operation.'],
#    ['After a visit to the agency\'s headquarters in Moscow in July, WADA director Olivier Niggli RUSADA announced that it "step on the right way" to make things work again.'],
#    ['In July, after an visit to the agency’s general headquarters in Moscow, WADA director Olivier Niggli announced RUSADA was “going the right way” to return to work.'],
#    ['In July after a visit to the headquarters of the institution in Moscow, WADA director Olivier Niggli declared that RUSADA "foot on the right way" to resume its business.'],
#    ['In July, after a visit to the headquarters at Moscow, WADA Director Olivier Niggli told RUSADA that “the right direction goes forward for the resettlement” of business.'],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA “fooded in the right direction to make things again”.'],
#    ['In July after a visit to the organization\'s headquarters in Moscow, the WADA Director Olivier Niggli RUSADA announced "the right direction is going on to return to work."'],
#    ['In July, after a visit to the agency’s central site in Moscow, WADA Director Olivier Niggli RUSADA stated that he was “bearing the right direction” for the regain to be the business.'],
#    ['In July, after a visit to the organization’s headquarters in Moscow, the WADA Director Olivier Niggli said RUSADA had been “going in the right direction” to be in the turn of the business.'],
#    ['In July after a visit to the body’s headquarters in Moscow, WADA Director Olivier Niggli announced that RUSADA was “going the right way” to return to work.'],
#    ['After a visit to the agency\'s headquarters in Moscow in July, the WADA Director Olivier Niggli announced that RUSADA is "through the correct direction" to react to the process.'],
#    ['After a visit to the agency’s main centre in Moscow in July, WADA Director Olivier Niggli RUSADA announced that he is “going on the right direction” to make things happen again.'],
#    ['In July, following a visit to the institution’s headquarters in Moscow, WADA’s Director Olivier Niggli said RUSADA “proved in the right direction to turn the jobs back to the road.”'],
#    ['In July, after a visit to the organization’s headquarters in Moscow, WADA’s director Olivier Niggli declared RUSADA has been “processing in the right direction” to become the job.'],
#    ['In July, after a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli RUSADA declared that he “being moving forward in the right direction” to become the new work.'],
#    ['In July, after a visit to the agency’s headquarters in Moscow, WADA Director Olivier Niggli said RUSADA had “curred in the right direction to get things to return.”'],
#    ['After a visit to the company\'s headquarters in Moscow in July, WADA Director Olivier Niggli RUSADA said that he was "going right towards a re-work."'],
#    ['After a visit to the organization’s headquarters in Moscow in July, WADA Director Olivier Niggli said that RUSADA was “going in the right way” to get things back into the way.'],
#    ['Following a visit to the agency’s headquarters in Moscow in July, WADA Director Olivier Niggli RUSADA declared that he “being in the right direction” towards the re-working processes.'],
#    ['In July, after a visit to the agency’s main office in Moscow, WADA Director Olivier Niggli said RUSADA has “currently made the right way to get things back.'],
#    ['In July, following a visit to the Agency\'s central headquarters in Moscow, WADA Director Olivier Niggli declared that RUSADA "progresses the right direction" to get things back.'],
#    ['In July after a visit to the agency\'s headquarters in Moscow, WADA Director Olivier Niggli said RUSADA was "reporting in the right direction" to rework.'],
#    ['After a visit to the headquarters of the agency in Moscow in July, WADA Director Olivier Niggli RUSADA announced that "the right direction is to move to the backward".'],
#    ['In July, following a visit to the institution’s headquarters in Moscow, WADA Director Olivier Niggli declared that RUSADA had “going in the right direction to be the rework.'],
#    ['In July, following a visit to the agency\'s headquarters in Moscow, Wada Director Olivier Niggli announced that RUSADA\'s "right forward" to re-making the work.'],
#    ["In July, after a visit to the agency's central center in Moscow, WADA Director Olivier Niggli said that the company 'goes the right direction' to regain."],
#    ["After a visit to the organization's headquarters in Moscow in July, WADA Director Olivier Niggli RUSADA said it had “goed the right path” to re-operation."],
#    ['In July, after a visit to the institution\'s headquarters in Moscow, WADA director Olivier Niggli RUSADA announced that he had "goed the right direction" to re-working.'],
#    ['In July, after a visit to the agency\'s headquarters in Moscow, WADA Director Olivier Niggli RUSADA announced that he was "going in the right direction" to turn the work into a reverse.']],
#   'ref': 'Following a visit to the organization\'s headquarters in Moscow in July, WADA Director General Olivier Niggli stated that RUSADA is "moving in the right direction" to be reinstated.'},
#  {'src': 'Gerçek liderlik de bunu kabul etmek anlamına geliyor.',
#   'candidates': [['Real leadership means accepting that.'],
#    ['A real leadership means accepting it.'],
#    ['The true leadership also means to accept this.'],
#    ['The true leadership means that I accept it.'],
#    ['A real leader also means to accept it.'],
#    ['True leadership also means accepting that.'],
#    ['But the true leadership means accepting it.'],
#    ['The true leadership means accepting that.'],
#    ['Really, leadership means to accept that.'],
#    ['The genuine leadership means accepting it.'],
#    ['True leadership means getting it in mind.'],
#    ['True leadership means accepting this.'],
#    ['A real leadership is accepting it.'],
#    ['True leadership also means acknowledging it.'],
#    ['And real leadership means accepting it.'],
#    ['Real leadership will be in acceptance.'],
#    ['True leadership is accepting it.'],
#    ['Really leadership means accepting that.'],
#    ['Really, leadership means to accept this.'],
#    ['The real leadership also means to accept it.'],
#    ['A real leadership means accepting it.'],
#    ['The true leadership means accepting it.'],
#    ['And a true leader means accepting it.'],
#    ['A true leadership means acceptering this.'],
#    ['True leadership means acceping it.'],
#    ['The real leadership is accepting that.'],
#    ['True leadership will also mean to accept it.'],
#    ['The real leadership means accepts it.'],
#    ['A real leadership means to accept it.'],
#    ['True leadership means accepting it.'],
#    ['A real leadership is also supposed to accept that.'],
#    ['True leadership means accepting that.'],
#    ['The real leadership means to accept that.'],
#    ['A real leadership is acceptering it.'],
#    ['The real leadership means accepting it.'],
#    ['The true leadership means accepting that.'],
#    ['True leadership is to agree.'],
#    ['Real leadership means accepting this.'],
#    ['True leadership means accepting that.'],
#    ['A true leadership will mean to accept that.'],
#    ['True leadership means being accepted.'],
#    ['True leadership also means accepting this.'],
#    ['Real leadership means that we accept this.'],
#    ['The real leadership is to agree.'],
#    ['True leadership means accepting it.'],
#    ['A real leadership is to accept that.'],
#    ['True leadership means accepting this.'],
#    ['And the real leadership means accepting it.'],
#    ['True leader will also mean accepting it.'],
#    ['A real leadership means accepting it.'],
#    ['The real leader is to accept it.'],
#    ['The real leadership means accepting this.'],
#    ['True leadership also means acknowledging.'],
#    ['True leadership will mean that of acknowledging it.'],
#    ['The true leadership will mean to accept.'],
#    ['A true leadership also means accepting it.'],
#    ['True leadership is to accept that.'],
#    ['And true leadership means accepting it.'],
#    ['True leadership means accepting it.'],
#    ['A real leader means accepting this.'],
#    ['True leadership means to accept that.'],
#    ['A true leader is accepting it.'],
#    ['Real leadership means accepting this.'],
#    ['Real leadership is to accept that.'],
#    ['The true leadership also means taking it into consideration.'],
#    ['The real leadership means accepting it.'],
#    ['The true leadership is to accept this.'],
#    ['True leadership is to accept that.'],
#    ['True leadership means accepting this.'],
#    ['A true leadership means accepting it.'],
#    ['Real leadership also means to accept it.'],
#    ['The real leadership also means to accept this.'],
#    ['Real leadership means to accept this.'],
#    ['The real leadership is to accept it.'],
#    ['A real leadership is to accept this.'],
#    ['True leadership means taking it into account.'],
#    ['A real leadership means to accept it.'],
#    ['True leadership means accepting it.'],
#    ['True leadership means being acknowledged by it.'],
#    ['A real leadership also means to accept it.'],
#    ['True leadership is to accept it.'],
#    ['True leadership is accepting it.'],
#    ['A true leadership also means acknowledging that.'],
#    ['True leadership means accepting that.'],
#    ['A true leader is accepting that.'],
#    ['True leadership means accepting this too.'],
#    ['And that real leadership is to accept it.'],
#    ['A true leader is to agree to that.'],
#    ['True leadership is to accept that.'],
#    ['True leadership means accepting that.'],
#    ['True leadership means to accept that.'],
#    ['True leadership means to accept it.'],
#    ['True leadership is accepting that.'],
#    ['True leadership means accepting that.'],
#    ['True leadership is to accept that.'],
#    ['The real leadership means accepting it.'],
#    ['The true leadership means accepting it.'],
#    ['True leadership also means getting it.'],
#    ['A true leadership means acceptering it.'],
#    ['True leader also means accepting it.'],
#    ['Real leadership means accepting it.'],
#    ['True leadership is to accept this.'],
#    ['True leadership means to accept it.'],
#    ['True leadership means that you are accepted.'],
#    ['The reality is that leadership is that it is accepted.'],
#    ['The real leadership means accepting it.'],
#    ['And true leadership is accepting.'],
#    ['The real leadership means accepting it.'],
#    ['True leadership means accepting it.'],
#    ['True leadership means accepting that.'],
#    ['The true leadership is to accept this.'],
#    ['True leadership also means accepting.'],
#    ['Real leader is to accept it.'],
#    ['The true leadership means to accept that.'],
#    ['A genuine leadership means to accept this.'],
#    ['The real leadership is that to accept that.'],
#    ['True leadership is to accept that.'],
#    ['A real leadership means accepting it too.'],
#    ['A true leader means acceptable.'],
#    ['A real leadership means accepting that.'],
#    ['The true leadership means to accept this.'],
#    ['The real leadership also means accepting it.'],
#    ['True leadership means that they are accepted.'],
#    ['The true leadership means accepting it.'],
#    ['True leadership means accepting that.'],
#    ['The true leadership means accepting this.'],
#    ['Really leadership means accepting it.'],
#    ['The true leader will agree.']],
#   'ref': 'And true leadership means accepting that.'}]
