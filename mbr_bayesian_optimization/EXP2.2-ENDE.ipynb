# %%
### EXP2.2: EN -> DE

# %%
### Install Required Packages
# !pip install jsonlines sentencepiece # nltk evaluate unbabel-comet accelerate
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.1.0)
# Installing collected packages: sentencepiece, jsonlines
# Successfully installed jsonlines-4.0.0 sentencepiece-0.1.99

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
drive_PATH = '../content/drive/MyDrive/Colab Notebooks/l101.experiments.1'
# Out:
# Mounted at /content/drive

# %%
# General
import numpy as np
import tqdm
import random

# Data
import jsonlines
import torch

# Model
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M") # Load Model
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M") # Load Tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# M2M100ForConditionalGeneration(
#   (model): M2M100Model(
#     (shared): Embedding(128112, 1024, padding_idx=1)
#     (encoder): M2M100Encoder(
#       (embed_tokens): Embedding(128112, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100EncoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): M2M100Decoder(
#       (embed_tokens): Embedding(128112, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100DecoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=128112, bias=False)
# )

# %%
### Dataset
test_tr_PATH = drive_PATH + '/data/datasets/test_tr_1000.jsonl'
test_de_PATH = drive_PATH + '/data/datasets/test_de_1000.jsonl'
test_tr = []
test_de = []

# with jsonlines.open(test_tr_PATH) as f:
#     for line in f.iter():
#         test_tr.append(line)
with jsonlines.open(test_de_PATH) as f:
    for line in f.iter():
        test_de.append(line)

# %%
# SRC: EN
# TGT: DE
src_lang = "en"
tgt_lang = "de"

# %%
### Setting the Language Configurations
dataset = test_de
tokenizer.src_lang = src_lang
print(len(dataset))
# Out:
# 1000

# %%
### Decoding: Epsilon Sampling

res = []
temperature = 1
epsilon_cutoff = 0.02
num_candidates = 128

for sent in tqdm.tqdm(dataset):
  #print(sent['en'])
  src_sent = sent[src_lang]
  encoded_src_sent = tokenizer(src_sent, return_tensors="pt").input_ids.to("cuda")

  candidates = []
  for idxc in range(num_candidates):
    tgt_tokens = model.generate(encoded_src_sent, forced_bos_token_id=tokenizer.get_lang_id(tgt_lang), do_sample=True, temperature=temperature, epsilon_cutoff=0.02, num_beams=1, early_stopping=False, num_return_sequences=1)
    tgt_sent = tokenizer.batch_decode(tgt_tokens, skip_special_tokens=True)
    candidates.append(tgt_sent)

  res_sent = {'src': sent[src_lang], 'candidates': candidates, 'ref':sent[tgt_lang]}
  res.append(res_sent)

cand_de_PATH = drive_PATH+ f'/exp2.2.ende-n{num_candidates}-t{temperature}-e{epsilon_cutoff}.jsonl'
with jsonlines.open(cand_de_PATH, mode='w') as writer:
    for item in res:
        writer.write(item)
# Out:
# 100%|██████████| 1000/1000 [17:21:55<00:00, 62.52s/it]

# %%
res[0]
# Out:
# {'src': 'However, the district is lacking additional personnel which it needs to overcome growing demands and duties.',
#  'candidates': [['Doch die Region fehlt dem zusätzlichen Personal, dem sie nötig ist, um die wachsenden Ansprüche und Verpflichtungen zu überwinden.'],
#   ['Der Distrikt ist jedoch von zusätzlichen Mitarbeitern fehl, die er brauchen, um steigende Anforderungen und Pflichten zu überwinden.'],
#   ['Doch die Umgebung fehlt zusätzlich Personalität, die es benötigt, um wachsende Forderungen und Schuld zu überwinden.'],
#   ['Doch die Bezirke fehlt mehr Personal, den sie benötigt, um die wachsenden Anforderungen und Pflichten zu überwinden.'],
#   ['Der Bezirk fehlt allerdings zusätzliches Personal, das er benötigt, um zunehmend anforderungen und Pflichten zu überwinden.'],
#   ['Allerdings fehlte der Bezirk zusätzliche Mitarbeiter, die es braucht, um die wachsenden Bedürfnisse und Pflichten zu überwinden.'],
#   ['Doch im Bezirk fehlt zusätzlich das Personal, das es braucht, um den wachsenden Nachforderungen und Pflichten zu überwinden.'],
#   ['Allerdings mangelt der Bezirke mehr Personal, die er braucht, um stetig wachsende Ansprüche und Pflichten zu überwinden.'],
#   ['Die Gebiet verpasst jedoch zusätzliche Mitarbeiter, die er benötigt, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Der Umkreis fehlt jedoch noch mehr Personal, den er benötigt, um immer wachsende Verlangen und Pflichten zu überwinden.'],
#   ['Doch das Gebiet fehlt zusätzlich Personal, dass es braucht, um die wachsenden Ansprüche und Pflichten zu übertragen.'],
#   ['Der Stadtrat hat jedoch noch einen zusätzlichen Personal, den es benötigt, um die wachsenden Anforderungen und Pflichten zu übertroffen.'],
#   ['Aber die Gegend mangelt an zusätzlichem Personal, das es braucht, um wachsende Ansprüche und Pflichten zu überwinden.'],
#   ['Der Umfeld ist jedoch mangelhaft für zusätzliches Personal, das er braucht, um wachsende Ansprüche und Pflichten zu überwinden.'],
#   ['Doch der Umkreis fehlt zusätzlichen Mitarbeiter, die er brauchen, um zunehmende Ansprüche und Verpflichtungen zu überwinden.'],
#   ['Die Gemeinde hat jedoch keine zusätzlichen Mitarbeiterschaft, die es braucht, um zunehmend wachsende Ansprüche und Pflichten zu überwinden.'],
#   ['Die Region ist allerdings noch nicht mehr an Mitarbeitern zu tun, die er benötigt, um sich an wachsenden Forderungen und Verpflichtungen zu bewältigen.'],
#   ['Die Gegend fehlt jedoch mehr Personal, den sie benötigt, um wachsende Forderung und Verpflichtungen zu überwinden.'],
#   ['Allerdings fehlt die Gegend noch zusätzliches Personal, das er brauchen, um die wachsenden Ansprüche und Pflichten zu überwinden.'],
#   ['Die Region mangelt noch Personal, den sie benötigt, um zu erreicht werden, um zunehmende Bedürfnisse und Aufgaben zu überwinden.'],
#   ['Dennoch fehlte der Stadtteil zusätzliches Personal, den er benötigt, um wachsende Forderungen und Pflichten zu überwinden.'],
#   ['Im Gegenteil fehlte der Bezirk aber zusätzliches Personal, welches er braucht, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Allerdings fehlt die Provinz zusätzlich noch Personal, die sie braucht, um immer stärkere Bedürfnisse und Pflichten zu überwunden.'],
#   ['Dennoch fehlt die Umgebung zusätzliches Personal, das sie benötigt, um wachsende Anforderungen und Verpflichtungen überwinden zu können.'],
#   ['Allerdings fehlt die Gegend zusätzlicher Personelle, die es benötigt, um wachsende Forderungen und Aufgaben zu überwinden.'],
#   ['Die Bezirke mangelt jedoch an zusätzlichen Personal, die es braucht, um die wachsenden Anforderungen und Aufgaben zu überwinden.'],
#   ['Der Bezirksmitglied fehlt allerdings, dass er zusätzliche Personal benötigt, die er benötigt, um immer wachsende Ansprüche und Verpflichtungen zu überwinden.'],
#   ['Das Gebiet fehlt allerdings, zusätzliches Personal, das es benötigt, um wachsende Erfordernisse und Pflichten zu überwunden.'],
#   ['Die Region fehlt aber an zusätzlichen Mitarbeiter, die sie benötigt, um wachsende Forderungen und Pflichten zu überwinden.'],
#   ['Die Bezirke fehlt jedoch mehr Personel und benötigt dazu, die zunehmende Ansprüche und Pflichten zu überwinden.'],
#   ['Allerdings fehlt der Bezirk mehr Personal, der für die immer höhere Forderungen und Pflichten gefordert wird.'],
#   ['Der Bezirk ist jedoch nicht an zusätzlichen Personal geblieben, die er benötigt, um wachsende Anforderungen und Verpflichtungen zu überwinden.'],
#   ['Dennoch fehlen das Gegend zusätzliche Personals, die es braucht, um sich mit wachsenden Ansprüchen und Pflichten zu befriedigen.'],
#   ['Allerdings fehlt das Gebiet zusätzliches Personal, das er benötigt, um den wachsenden Ansprüchen und Pflichten zu überwunden.'],
#   ['Die Umgebung fehlt jedoch noch mehr Personale, die für die übertroffenen Anforderungen und Pflichten benötigt werden.'],
#   ['Allerdings fehlt der Bezirk zusätzliche Mitarbeiter, die es braucht, um wachsende Anforderungen und Pflichten zu überwinden.'],
#   ['Dennoch fehlt der Bereich noch mehr Personal, den er brauchen, um steigende Ansprüche und Pflichten zu übertreffen.'],
#   ['Allerdings fehlt das Viertel zusätzliches Personal, das es braucht, um steigende Forderung und Pflichten zu überwinden.'],
#   ['Allerdings fehlt der Bezirke noch mehr Personelle, die er braucht, um die wachsenden Ansprüche und Pflichten zu überwinden.'],
#   ['Dennoch fehlt das Viertel zusätzlich an Personal, das es braucht, um die wachsenden Anforderungen und Pflichten zu überwinden.'],
#   ['Die Provinz hat jedoch zusätzliches Personal, das es nötig hat, um die wachsenden Forderungen und Pflichten zu überwinden.'],
#   ['Das Gegend hat aber noch weniger Personal, welches es nötig ist, die zunehmenden Ansprüche und Pflichten zu überwinden.'],
#   ['Die Gegend fehlt jedoch mit zusätzlichen Personal, die für die übertragung der zunehmenden Anforderungen und Pflichten notwendig ist.'],
#   ['Im Bezirk ist allerdings kein zusätzliches Personal gebraucht, welches es brauchen wird, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Doch das Gebiet fehlt dem zusätzlichen Personal, das es benötigt, um die wachsenden Anforderungen und Verpflichtungen zu überwinden.'],
#   ['Allerdings fehlt der Gebiet zusätzliche Personal, die er benötigt, um die wachsenden Forderungen und Pflichten zu überwinden.'],
#   ['Der Gebiet mangelt allerdings noch noch mehr Personal, den er benötigt, um zunehmende Ansprüche und Pflichten zu überwinden.'],
#   ['Die Umgebung fehlt allerdings noch mehr Personal, die sie benötigt, um die wachsenden Anforderungen und Pflichten zu überwinden.'],
#   ['Der Bezirk fehlt jedoch, zusätzliches Personal, das er benötigen, um zunehmende Ansprüche und Pflicht überwunden.'],
#   ['Allerdings fehlt die Gebiete dem zusätzlichen Personal, das sie brauchen, um zunehmende Anforderungen und Verpflichtungen zu überwinden.'],
#   ['Doch der Drittstaat fehlt zusätzlich dem Personal, den er brauchen, um wachsende Nachfrage und Pflichte zu übertroffen.'],
#   ['Das Gebiet mangelt aber zusätzliche Personal, die es braucht, um wachsende Forderungen und Schuld zu überwinden.'],
#   ['Die Gegend ist jedoch mangelhaft, um zusätzliche Mitarbeiter zu überwinden, die sie wächst Forderungen und Pflichten.'],
#   ['Das Gegend fehlt jedoch zusätzlich an Personal, das es braucht, um die wachsenden Forderungen und Pflichten zu überwinden.'],
#   ['Allerdings fehlt der Bezirk zusätzlich Personal, den es benötigt, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Die Bezirk hat jedoch noch nicht mehr Personal, das sie benötigt, um immer wachsende Forderungen und Pflichten zu überwältigen.'],
#   ['Die Region mangelt jedoch mehr Personal, die es braucht, um wachsende Anforderungen und Verpflichtungen zu überwinden.'],
#   ['Allerdings fehlt die Region dem Personal zusätzlich, den sie braucht, um die wachsenden Forderungen und Schuld zu überwinden.'],
#   ['Die Stadt ist jedoch an zusätzlichen Personal gebraucht, die sie benötigt, um die wachsenden Forderungen und Pflichten zu überwinden.'],
#   ['Die Region fehlt jedoch zusätzlicher Mitarbeiter, die er benötigt, um die wachsenden Ansprüche und Pflichten zu überwunden.'],
#   ['Das Viertel fehlt jedoch zusätzlicher Personal, das es benötigt, um zunehmende Ansprüche und Pflichten zu überwinden.'],
#   ['Das Distrikt fehlt jedoch noch mehr Personal, was es benötigt, um die steigenden Forderungen und Pflichten zu überwinden.'],
#   ['Die Umgebung hat jedoch keine zusätzlichen Mitarbeiter, die er benötigt, um die wachsenden Anforderungen und Aufgaben zu überwinden.'],
#   ['Doch die Gegend mangelt zusätzlich Personal, das sie brauchen, um die zunehmenden Anforderungen und Pflichten zu überwinden.'],
#   ['Dennoch fehlt der Bezirk zusätzlicher Mitarbeiter, die es braucht, um immer wachsende Forderungen und Schuldes überwinden.'],
#   ['Die Gegend fehlt allerdings zusätzliches Personal, das es benötigt, um immer wachsende Ansprüche und Pflichten zu übertreffen.'],
#   ['Der Stadt fehlt jedoch zusätzliches Personal, das es benötigt, um wachsende Erforderungen und Pflichten zu überwinden.'],
#   ['Die Stadt hat jedoch keinen zusätzlichen Personal, mit dem die zunehmenden Forderungen und Pflichten überwinden können.'],
#   ['Allerdings fehlt es dem Stadtteil noch mehr Personalität, die sie benötigt, um zunehmend steigende Anforderungen und Pflichten zu überwinden.'],
#   ['Die Provinz fehlt jedoch zusätzlich an Personal, welches sie benötigt, um immer höhere Ansprüche und Verpflichtungen zu überwinden.'],
#   ['Das Gebiet fehlt jedoch zusätzlich an Personal, das es benötigt, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Allerdings fehlt der Bezirk zusätzlich Personal, welches es benötigt, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Die Provinz hat allerdings keine zusätzlichen Personal, die sie benötigen soll, um wachsende Forderungen und Verpflichtungen zu überwinden.'],
#   ['Allerdings fehlt die Bezirksgruppe zusätzlichen Mitarbeiter, die sie benötigt, um zunehmende Ansprüche und Pflichten zu überwinden.'],
#   ['Die Region fehlt jedoch zusätzlich an Mitarbeitern, die es braucht, um steigende Anforderungen und Pflichten zu überwinden.'],
#   ['Dennoch fehlt der District zusätzlichen Personal, der benötigt, um die wachsenden Forderungen und Pflicht zu überwinden.'],
#   ['Die Region fehlt aber an zusätzlichen Mitarbeiter, die es braucht, um wachsende Anforderungen und Pflichten zu übertreffen.'],
#   ['Doch das Distrikt fehlt zusätzlichen Mitarbeitern, die es brauchen, um wachsende Verpflichtungen und Anforderungen zu überwinden.'],
#   ['Der Umkreis ist jedoch mit einem zusätzlichen Personal abgeschlossen, das er benötigt, um die wachsenden Forderungen und Pflichten zu überwinden.'],
#   ['Allerdings fehlt der Bezirk zusätzliche Mitarbeiter, die er benötigt, um die wachsenden Anforderungen und Pflichten zu überwinden.'],
#   ['Allerdings fehlt der Bezirk zusätzlicher Personalität, die er benötigt, um wachsende Anforderungen und Pflichten zu überwinden.'],
#   ['Der Distrikt mangelt aber zusätzliche Mitarbeiter, die er braucht, um die wachsende Anforderungen und Pflichten zu überwinden.'],
#   ['Der District verliert jedoch zusätzliche Mitarbeiter, die er benötigt, um wachsende Forderungen und Pflichten zu überwinden.'],
#   ['Das Gebiet hat jedoch keinen zusätzlichen Personal, den es benötigt, um zunehmende Forderungen und Verpflichtungen zu überwinden.'],
#   ['Doch der Stadtteil fehlt zusätzlich an Mitarbeiter, die er benötigt, um die wachsenden Nachfrage und Pflichten zu überwinden.'],
#   ['Die Stadt hat aber noch weniger Mitarbeiter, die sie benötigt, um sich gegen die wachsenden Forderungen und Aufgaben zu bewältigen.'],
#   ['Dennoch fehlt der Bezirk mehr Personal, die er benötigt, um die wachsenden Ansprüche und Pflichten zu überwinden.'],
#   ['Allerdings fehlt der Bezirk noch mehr Personal, für das er die wachsenden Ansprüche und Verpflichtungen zu überwinden muss.'],
#   ['Der Bezirk fehlt jedoch noch mehr Personal, das es braucht, um das wachsende Bedürfnis und die Aufgaben zu überwinden.'],
#   ['Doch die Gegend fehlt zusätzlich Personalmannschaft, die es benötigt, um wachsende Bedürfnisse und Schuld zu überwinden.'],
#   ['Das Gebiet mangelt aber zu einem zusätzlichen Personal, den es brauchen, um die zunehmenden Forderungen und Pflichten zu überwinden.'],
#   ['Die Bezirke mangelt jedoch zusätzlich Personal, die sie benötigt, um zunehmende Ansprüche und Pflichten zu überwinden.'],
#   ['Die Region fehlt jedoch mehr Personal, die für das Überleben von zunehmenden Ansprüchen und Schulden notwendig ist.'],
#   ['Die Gegend fehlt allerdings an zusätzlichen Personal, die es braucht, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Das Gebiet fehlt jedoch zusätzlich an Mitarbeiter, die es benötigt, um wachsende Ansprüche und Pflichten zu überwinden.'],
#   ['Die Gemeinde fehlt jedoch mit zusätzlichen Personalen und benötigt diese, um wachsende Forderung und Verpflichtungen überwältigen zu können.'],
#   ['Der Bezirk fehlt jedoch zusätzlich an Personalen, die er benötigt, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Der Distrikt ist jedoch an zusätzlichen Personal gebunden, den er benötigt, um die wachsenden Ansprüche und Schuld zu überwinden.'],
#   ['Der Gegend hat jedoch keine weiteren Personals, die es benötigt, um wachsende Forderungen und Schulden zu überwinden.'],
#   ['Die Stadt fehlt jedoch, die erforderlich sind, um zunehmende Anforderungen und Pflichten zu überwinden.'],
#   ['Der Bereich fehlt jedoch zusätzlich an Mitarbeiter, die er benötigt, um die wachsenden Forderungen und Pflichten zu überwinden.'],
#   ['Doch die Region fehlt an zusätzlichem Personal, was sie brauchen, um sich zunehmende Forderungen und Pflichten zu überwältigen.'],
#   ['Die Region fehlt jedoch zusätzlich an Personal, das für die überwältigung der wachsenden Anforderungen und Pflicht erforderlich ist.'],
#   ['Aber es fehlt noch mehr Mitarbeiter, die die ständig wachsenden Ansprüche und Pflicht überwinden müssen.'],
#   ['Allerdings fehlt der Bezirk zusätzlich, die es benötigt, um wachsende Anforderungen und Pflichten zu überwinden.'],
#   ['Dennoch fehlen die Bezirke zusätzlich Mitarbeiter, die sie überwinden müssen, um die steigenden Anforderungen und Pflichten zu überwinden.'],
#   ['Die Stadt fehlt jedoch mehr Personale, die sie benötigt, um die steigenden Ansprüche und Pflichten zu überwunden.'],
#   ['Die Umgebung fehlt jedoch noch mehr Personal, den sie benötigt, um die wachsenden Ansprüche und Schuld zu überwinden.'],
#   ['Der Bezirk hat jedoch noch ein zusätzliches Personal, dessen Bedarf es hat, um stetig wachsende Ansprüche und Verpflichtungen zu überwinden.'],
#   ['Der Bezirke hat jedoch noch keinen zusätzlichen Personal, den er benötigt, um die wachsenden Anforderungen und Pflichten zu überwinden.'],
#   ['Das Gebiet hat jedoch noch einen zusätzlichen Personal, den es benötigt, um die wachsenden Forderungen und Pflichten zu überwältigen.'],
#   ['Allerdings fehlt der Viertel zusätzliches Personal, das er braucht, um die wachsenden Anforderungen und Aufgaben überwinden.'],
#   ['Der Bezirk ist jedoch fehlt, mehr Personal, die er benötigt, um wachsende Ansprüche und Pflichten zu überwinden.'],
#   ['Doch der Bezirk fehlt zusätzlich an Personal, das es benötigt, um die wachsenden Anforderungen und Verpflichtungen zu überwunden.'],
#   ['Dennoch fehlt der Gebiet mehr Personal, den er braucht, um die wachsenden Ansprüche und Pflichten zu überwinden.'],
#   ['Allerdings fehlt die Gegend zusätzlicher Personal, mit dem sie die zunehmenden Bedürfnisse und Pflichten überwinden muss.'],
#   ['Allerdings fehlt der Bezirk zusätzliches Personal, den es braucht, um wachsende Forderungen und Pflichten zu überwinden.'],
#   ['Die Stadt fehlt aber noch an zusätzlicher Personell, die es braucht, um die wachsenden Anforderungen und Verpflichtungen zu überwinden.'],
#   ['Allerdings fehlt der Bezirk zusätzliche Personal, die es braucht, um die wachsenden Anforderungen und Schulden zu überwinden.'],
#   ['Das Land hat aber noch wenig Personal und benötigt die Steigerungen und Pflichten zu überwinden.'],
#   ['Doch die Umgebung fehlt zusätzliches Personal, das es braucht, um die wachsenden Ansprüche und Verpflichtungen zu überwinden.'],
#   ['Die Provinz hat jedoch nicht mehr Personal, was sie benötigen, um steigende Nachfrage und Verpflichtungen zu überwinden.'],
#   ['Doch die Gegend fehlt zusätzlich Personal, die sie benötigt, um zunehmende Forderungen und Verpflichtungen zu überwinden.'],
#   ['Die Gemeinde fehlt aber zusätzlich an Personal, die sie benötigt, um wachsende Verlangen und Pflichten zu überwinden.'],
#   ['Dennoch fehlt der District noch mehr Personal, die es braucht, um den wachsenden Ansprüchen und Pflichten zu überwinden.'],
#   ['Aber das Gegend fehlt noch mehr Mitarbeiter, die es braucht, um die wachsenden Forderungen und Pflichten zu überwinden.'],
#   ['Das Bezirk fehlt jedoch zusätzlich an Personal, das es braucht, um die wachsenden Anforderungen und Pflichten zu überwinden.'],
#   ['Der Bezirk ist jedoch fehlt zusätzlich Personal, die es braucht, um die wachsenden Anforderungen und Verpflichtungen zu überwinden.']],
#  'ref': 'Dennoch fehlt dem Kreis weiter Personal, um die gestiegenen Anforderungen und Aufgaben bewältigen zu können.'}
