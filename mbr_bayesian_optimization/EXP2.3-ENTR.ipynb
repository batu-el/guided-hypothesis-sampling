# %%
### EXP2.3: EN -> TR

# %%
### Install Required Packages
# !pip install jsonlines sentencepiece # nltk evaluate unbabel-comet accelerate
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.1.0)
# Installing collected packages: sentencepiece, jsonlines
# Successfully installed jsonlines-4.0.0 sentencepiece-0.1.99

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
drive_PATH = '../content/drive/MyDrive/Colab Notebooks/l101.experiments.1'
# Out:
# Mounted at /content/drive

# %%
# General
import numpy as np
import tqdm
import random

# Data
import jsonlines
import torch

# Model
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M") # Load Model
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M") # Load Tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# M2M100ForConditionalGeneration(
#   (model): M2M100Model(
#     (shared): Embedding(128112, 1024, padding_idx=1)
#     (encoder): M2M100Encoder(
#       (embed_tokens): Embedding(128112, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100EncoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): M2M100Decoder(
#       (embed_tokens): Embedding(128112, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100DecoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=128112, bias=False)
# )

# %%
### Dataset
test_tr_PATH = drive_PATH + '/data/datasets/test_tr_1000.jsonl'
test_de_PATH = drive_PATH + '/data/datasets/test_de_1000.jsonl'
test_tr = []
test_de = []

with jsonlines.open(test_tr_PATH) as f:
    for line in f.iter():
        test_tr.append(line)
# with jsonlines.open(test_de_PATH) as f:
#     for line in f.iter():
#         test_de.append(line)

# %%
# SRC: EN
# TGT: TR
src_lang = "en"
tgt_lang = "tr"

# %%
### Setting the Language Configurations
dataset = test_tr
tokenizer.src_lang = src_lang
print(len(dataset))
# Out:
# 1000

# %%
### Decoding: Epsilon Sampling

res = []
temperature = 1
epsilon_cutoff = 0.02
num_candidates = 128

for sent in tqdm.tqdm(dataset):
  #print(sent['en'])
  src_sent = sent[src_lang]
  encoded_src_sent = tokenizer(src_sent, return_tensors="pt").input_ids.to("cuda")

  candidates = []
  for idxc in range(num_candidates):
    tgt_tokens = model.generate(encoded_src_sent, forced_bos_token_id=tokenizer.get_lang_id(tgt_lang), do_sample=True, temperature=temperature, epsilon_cutoff=0.02, num_beams=1, early_stopping=False, num_return_sequences=1)
    tgt_sent = tokenizer.batch_decode(tgt_tokens, skip_special_tokens=True)
    candidates.append(tgt_sent)

  res_sent = {'src': sent[src_lang], 'candidates': candidates, 'ref':sent[tgt_lang]}
  res.append(res_sent)

cand_de_PATH = drive_PATH+ f'/exp2.3.entr-n{num_candidates}-t{temperature}-e{epsilon_cutoff}.jsonl'
with jsonlines.open(cand_de_PATH, mode='w') as writer:
    for item in res:
        writer.write(item)
# Out:
# 100%|██████████| 1000/1000 [16:36:15<00:00, 59.78s/it]

# %%
res
# Out:
# [{'src': 'He made no mention of the legal challenge filed against his prior position in a federal appeals court.',
#   'candidates': [['Bir federal itiraz mahkemesinde önceki pozisyonuna karşı sunulan hukuki zorunluluğu de bahsetmemişti.'],
#    ["Bir Federal Başvuru Mahkemesi'nde önceki pozisyona karşı yapılmış hukuki sorunu henüz belirtmemişti."],
#    ['Bir federal itiraz mahkemesinde önceki pozisyonuna karşı itiraz edildi.'],
#    ['Bir Federal Yargı Mahkemesinde önceki konumuna yönelik bir yasal ihtilafın kaydedilmemesi gerekmektedir.'],
#    ['Bir federal dava mahkemesinden önceki göreve karşı dava alan yasal zorluklardan bahsetmedi.'],
#    ['Bir federal başvuru mahkemesinde önceki konumuna karşı başvuran yasal meydan okumayı henüz bahsetmedi.'],
#    ['Bir federal başvuru mahkemesinde ön pozisyonuna karşı sunulan yasal dava hakkında hiç söz vermedi.'],
#    ['Bir federal başvuru mahkemesinde önceki konumuna karşı dava açılmasına ilişkin bir şey söylemedi.'],
#    ["Bir Federal Başvuru Mahkemesi'nde önceden görevine karşı sunulan hukuki sorunun bir anlamı yoktu."],
#    ['Bir federal ceza Mahkemesine önceki konuma yönelik olan yasal sorunu hiç belirtmedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonu karşısında yapılan yasal soruşturmayı dile getirmedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna itiraz ettiği yasal talep hakkında konuşmadı.'],
#    ['Bir federal dava mahkemesi ön pozisyonuna karşı yasal sorun hakkında hiçbir açıklama yapılmadı.'],
#    ['Bir federal dava mahkemesinde ön konumuna karşı dava edilen yasal sorunu da belirtmemişti.'],
#    ['Bir federal itiraz mahkemesinde önceden yaptığı pozisyona karşı yapılan hukuki sorguyu anlatmamıştır.'],
#    ['Bir federal itiraz mahkemesine önceki pozisyonuna karşı yapılan yasal sorun hakkında hiçbir şey söylemedi.'],
#    ['Bir Federal Başvuru Mahkemesi’nde önceki konuya karşı yasal olarak sunulan talepler hakkında hiçbir şey söylemedi.'],
#    ['Bir Federal Başvuru Mahkemesinde önceki pozisyonuna karşı verilen yasal dava hakkında hiçbir ifade yapmadı.'],
#    ["Bir Federal Ceza Mahkemesi'nde önceki pozisyonuna karşı sunulan yasal dava hakkında henüz bir şey söylenmedi."],
#    ['Bir federal itiraz mahkemesinde ön pozisyonuna karşı başlatılan yasal meydan hakkında söz vermedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyona karşı yapılmış olan yasa davalarını ifade etmedi.'],
#    ['Bir federal başvuru mahkemesinde ön pozisyonuna karşı verilen hukuki zorunluluk söz konusu değil.'],
#    ['Bir federal dava mahkemesinde önceki görevi karşı verilen yasal sorunu anlattı.'],
#    ['Federal Ceza Mahkemesi’nde önceki pozisyonuna karşı yapılan yasal dava hakkında hiçbir açıklama yapılmadı.'],
#    ['Bir Federal Savcılık Mahkemesinde önceki pozisyonuna karşı sunulan hukuki meydan okumayı dile getirmedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı itiraz edilen yasal sorunun hiç bahsetmemiştir.'],
#    ["Bir Federal Ceza Mahkemesi'nde önceki konumuna karşı yasal olarak sunulan sorunun söz konusu olmadığını belirtmemiştir."],
#    ['Federal bir dava mahkemesinde ön pozisyonuna yönelik yasal meydan okuma konusundan söz edilmemişti.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı verilen yasal zorunlamalara bahsetmedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna itiraz edilen yasal meydan okumayı hiç belirtmedi.'],
#    ['Federal itiraz mahkemesinde bir ön pozisyona karşı yapılan yasal meydan okumayı belirtmedi.'],
#    ["Federal Bir Ceza Mahkemesi'nde görevinden önce yaptığı hakemle ilgili herhangi bir sorunu reddedemedi."],
#    ['Bir federal itiraz mahkemesinde önceki konuyla ilgili olarak verilen yasal sorgunun kaydını vermedi.'],
#    ['Bir federal dava mahkemesinde önceki pozisyonuna karşı yapılmış bir yasal tartışma hakkında yorum yapmadı.'],
#    ['Bir federal başvuru mahkemesinde önceki göreviyle karşı savunucularının başlatılan yasal zorunluluk hakkında henüz bir ifade vermedik.'],
#    ['Bir federal dava mahkemesinde önceki görevine karşı verilen yasal meydan okumadan bahsetmedi.'],
#    ['Bir federal dava mahkemesinde önceki konuma karşı dava üzerine itiraz etti.'],
#    ['Federal Ceza Mahkemesinde ön pozisyonuna karşı yapılan yasal ihtilafın hiçbir anında söz konusu olmadığı belirtildi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı dava açılan yasal zorunluluklardan bahsetmiyordu.'],
#    ['Federal başvuru mahkemesinde önceki konudaki sorunu ile ilgili herhangi bir söz konusu değil.'],
#    ['Bir Federal Ceza Mahkemesinde önceki pozisyonuna karşı yapılmış yasal dava hakkında bir yorum yapmadı.'],
#    ['Federal Mahkemede ön pozisyonuna karşı savunan yasal soruşturma hakkında hiçbir açıklama yapmadı.'],
#    ['Bir federal dava mahkemesinde önceki konuma karşı yapılan hukuki zorluktan bahsetmedi.'],
#    ["Bir Federal Ceza Mahkemesi'nde önceki pozisyonuna karşı yasal sorunun kaydedilmesi hakkında bir açıklama yapmadı."],
#    ['Bir federal dava mahkemesinde ön pozisyonuna karşı sunulan yasal sorunun kaydedilmesine dair bir söz vermedi.'],
#    ['Bir Federal Ceza Mahkemesi’nde önceki konumuna karşı başvuru yapan yasal meydan okumayı dile getirmedi.'],
#    ['Bir Federal Savcılık Mahkemesinde ön pozisyonuna karşı yasal olarak ortaya çıkan zorunluluk hakkında hiçbir şey ifade etmemiştir.'],
#    ['Bir Federal Başvuru Mahkemesi’nde önceki pozisyonuna karşı yaptığı yasal meydan okumayı belirtmedi.'],
#    ['Bir federal dava mahkemesinde ön pozisyonuna karşı yasal dava hakkında hiçbir şey söylemedi.'],
#    ['Bir federal dava mahkemesinde önceki pozisyonuna karşı yapılan hukuki sorunun hiç bahsetmemiştir.'],
#    ['Bir Federal dava mahkemesinin önceki konumu üzerine yasa konusundaki dava hakkında hiçbir şey söylemedi.'],
#    ["Federal bir Başvuru Mahkemesi'ndeki ön görevine karşı yapılan yasal sorunu hiç dikkate almadı."],
#    ['Federal bir dava mahkemesinde önceki pozisyonuna karşı verilen hukuki sorunun söz konusu olmadığı belirtiliyor.'],
#    ['Bir Federal Ceza Mahkemesine önceden pozisyonuna itiraz edilen yasal zorunluluk hakkında henüz hiç bahsetmemiştir.'],
#    ['Federal Başvuru Mahkemesinde önceden bir pozisyonu karşısında yaptığı yasal meydan okumaya dava açmadı.'],
#    ['Bir federal dava mahkemesinde önceki konuma karşı sunulan yasal sorunun söz konusu olmamıştır.'],
#    ['Bir federal dava mahkemesinde önceki pozisyonuna karşı sunulan yasal meydan okumadan hiç söz etmemiş.'],
#    ['Bir federal dava mahkemesinde önceki pozisyona karşı yapılan hukuki zorunluluğun hiçbir şekilde anlatılmasına gerek yoktur.'],
#    ['Bir federal dava mahkemesine önceki görevi karşı yasal olarak sunulan soru hakkında hiçbir şey söylemedim.'],
#    ["Bir federal itiraz mahkemesi'nde önceki pozisyonuna karşı itiraz ettiği hukuki bir talepleri ifade etmedi."],
#    ["Federal bir Ceza Mahkemesi'nde önceki pozisyonuna karşı dava açılan yasal dava hakkında bahsetmedi."],
#    ['Bir federal başvuru mahkemesinde önceki görevine karşı yapılan yasal dava hakkında henüz bir şey söylemedi.'],
#    ['Bir federal dava mahkemesinde önceki konusuna yönelik yasal meydan okuma hakkında bahsetmedi.'],
#    ['Federal bir itiraz mahkemesinde ön pozisyona karşı çıkan yasal talepleri bahsetmedi.'],
#    ['Bir federal dava mahkemesine karşı dava açıkladığı iddiası açıklanmamış.'],
#    ['Bir Federal Yargı Mahkemesinde önceki pozisyonuna karşı yaptığı yasal meydan okumayı hiç bahsetmemiştir.'],
#    ['Federal bir Başvuru Mahkemesinde önceki görevine karşı verilen hukuki zorunluluk hakkında hiçbir söz vermedi.'],
#    ['Bir federal itiraz mahkemesi için ön pozisyonuna karşı sunulan hukuki soruşturma hakkında hiç bahsetmedi.'],
#    ['Federal bir dava mahkemesinde önceki konumuna karşı yapılmış yasal meydan okumaya dair hiçbir ifade vermedi.'],
#    ["Federal bir dava mahkemesi'nde önceki pozisyonuna karşı yapılan yasal zorunluluğundan bahsetmemişti."],
#    ['Federal başvuru mahkemesi üyeliği öncesinde yasal soruşturma konusundaki hiçbir yorum yapmadı.'],
#    ['Bir federal başvuru mahkemesinde ön pozisyonu karşı yapılan yasal sorunu hiçbir şekilde dile getirmedi.'],
#    ['Federal Yargı Mahkemesine önceki konumuyla ilgili soruşturma konusu belirtilmemiştir.'],
#    ['Federal başvuru mahkemesinde önceki pozisyonuna karşı yapılan yasal zorunluluklar hakkında hiçbir söz verilmedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı yapılmış hukuki zorluktan bahsetmedi.'],
#    ["Bir Federal Ceza Mahkemesi'nde önceki pozisyonuna karşı yasal sorunun cevapsını vermedi."],
#    ['Bir federal itiraz mahkemesinde önceki pozisyonuna karşı verilen yasal meydan okuma hakkında hiçbir açıklama yapmadı.'],
#    ['Federal dava mahkemesinde ön pozisyonuna itiraz edilen hukuki zorlama hakkında söz konusu olmadığını söyledi.'],
#    ['Bir federal başvuru mahkemesinde önceki görevine karşı yapılmış hukuki soru hakkında hiçbir yorum yapmadı.'],
#    ['Bir Federal Ceza Mahkemesi’nde önceki görevine yönelik hukuki ihtilaf hakkında hiçbir söz vermedi.'],
#    ['Bir federal ceza mahkemesine önceki pozisyonuna karşı yapılan yasal zorunluluktur hakkında konuşmadı.'],
#    ["Federal Bir Ceza Mahkemesi'nde önceki pozisyonuna karşı verilen yasal davaları söylemiyordu."],
#    ['Bir Federal İtiraf Mahkemesi’nde önceden yer aldığı kanunlara karşı yapılan hakemlik sorunu hiç belirtilmedi.'],
#    ["Federal Başvuru Mahkemesi'nde önceki pozisyonuna karşı yasal sorunun kaydedilmesi konusunda henüz konuşmamıştır."],
#    ["Bir Federal Başvuru Mahkemesi'nde önceki konumuna karşı dava edilen yasal meydan okuma hakkında hiçbir söz vermedi."],
#    ['Bir federal dava mahkemesinde önceki görevine karşı yapılan yasal soruşturma hakkında konuşmadı.'],
#    ['Federal bir başvuru mahkemesine karşı ön pozisyonuna itiraz ettiği yasal sorumluluğu hakkında hiçbir şey söylemedi.'],
#    ['Bir federal dava mahkemesinde önceki pozisyonuna karşı verilen yasal sorun söz konusu değildir.'],
#    ['Bir Federal Ceza Mahkemesi’nde ön pozisyonu karşısında yasal bir talep hakkında hiçbir şey söylemedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı yapılan yasal meydan okumayı anlatılmamıştı.'],
#    ['Federal bir itiraz mahkemesinde önceki görevi karşı yapılan yasal sorunlardan söz vermedi.'],
#    ['Bir federal dava mahkemesinde önceki pozisyonuna karşı sunulan yasal zorunlulukla ilgili henüz bir şey söylemedi.'],
#    ['Bir Federal Davet Mahkemesinde önceki pozisyonuna karşı yapılan yasal sorun hakkında hiç bahsetmemiştir.'],
#    ['Federal İstifa Mahkemesi’nde önceki pozisyonuna karşı yapılan yasal davaları henüz dikkate almadı.'],
#    ['Bir federal başvuru mahkemesine önceki görevine karşı yasal olarak dava açılmadı.'],
#    ['Bir federal dava mahkemesinde önceki konumuna karşı itiraz ettiği yasal sorunla ilgili hiçbir yorum yapmadı.'],
#    ["Federal Mahkeme'de önceki görevine karşı dava açan yasal sorunun bulunmadığına dair bir yorum yapmamıştır."],
#    ['Federal bir dava mahkemesinde önceki pozisyona karşı yaptığı yasal sorunun hiç bahsetmediğini belirtti.'],
#    ['Bir federal başvuru mahkemesinde önceki konuma itiraz ettiği yasal zorunluluk hakkında bir şey söylemedi.'],
#    ['Bir federal davalarda önceden görevine karşı yapılan hukuki zorunlulukları dile getirmedi.'],
#    ['Federal Başvuru Mahkemesinde önde gelen pozisyonuna karşı yasal soruşturmayı kaydetti.'],
#    ['Bir federal dava mahkemesinde ön konuma itiraz edilen yasal meydan okumayı söylemedi.'],
#    ['Bir Federal Başvuru Mahkemesinde önceki konudaki kanunla ilgili soru sorulmadığını belirtti.'],
#    ['Federal başvuru mahkemesinde önceki konumu karşı çıkan hukuki meydan okumaları henüz bahsetmemişti.'],
#    ['Bir federal başvuru mahkemesinde önceki konumuna karşı sunulan yasal talep hakkında bahsetmiyordu.'],
#    ['Federal Mahkemede önceki pozisyonuna karşı yapılan hakem sorunu hakkında hiçbir söz vermedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı yapılan yasal sorunu söylememiştir.'],
#    ['Bir federal başvuru mahkemesinde ön pozisyonuna karşı savunma davasını anlattı.'],
#    ['Bir federal başvuru mahkemesi için önceki pozisyonuna karşı sunulan yasal taleplere bahsetmedi.'],
#    ['Bir federal dava mahkemesine önceki pozisyonu karşısındaki hukuki soruşturma konusu hakkında bir açıklama yapılmadı.'],
#    ['Bir federal başvuru mahkemesine yönelik önceki konuya karşı itirazın yasal sorunu hakkında konuşmadı.'],
#    ['Bir Federal Yargı Mahkemesi’nde önceki görevi karşılık verdiği hukuki meydan okuma hakkında hiçbir şey söylememişti.'],
#    ['Bir federal dava mahkemesinde önceki görevi için sunulmuş yasal meydan okuma hakkında bir şey söylemedi.'],
#    ["Federal Ceza Mahkemesi'nde önceki pozisyonuna karşı yapılan hukuk meydanına dair bir söz vermedi."],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı yapılan yasal zorunluluktan bahsetmedi.'],
#    ['Bir federal itiraz mahkemesinde önceki pozisyonuna karşı verilen hukuki zorluklardan bahsetmemişti.'],
#    ['Bir federal dava mahkemesinde ön konumuna karşı itiraz edilen yasal sorunun hiçbir söz vermedi.'],
#    ['Bir federal dava mahkemesinde ön pozisyonuna karşı yasal olarak sunulan sorunun da dikkate alınmamıştı.'],
#    ['Bir federal ceza mahkemesinde önceki pozisyonuna karşı sunulan yasal zorunluluktan bahsetmedi.'],
#    ['Bir federal dava mahkemesi ön pozisyonuna karşı yapılan yasal sorunu anlatmadığını belirtti.'],
#    ["Federal Yargı Mahkemesi'nde önceki pozisyonuna karşı verilen yasal soru hakkında hiçbir yorum yapmadı."],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonuna karşı sunulan hukuki sorunun kaydedilmesini yapmadı.'],
#    ['Bir federal başvuru mahkemesinde önceki duruşuna karşı yapılan yasal meydan okumaya dair hiç ifade vermedi.'],
#    ['Bir federal dava mahkemesinde önceki pozisyonuna karşı yasal talepler hakkında hiçbir şey belirtmedi.'],
#    ['Bir federal dava mahkemesinde önceki pozisyonuna karşı dava hakkı hakkında bahsetmiyordu.'],
#    ['Bir federal dava mahkemesinin önceki pozisyonuna karşı yasal meydan okuma hakkında hiçbir ifade göstermedi.'],
#    ['Bir federal başvuru mahkemesinde önceki pozisyonu karşı dava edilen yasal meydan okumayı konuşmadı.'],
#    ["Bir Federal Ceza Mahkemesi'nde önceki konumuna yönelik yasal zorunluluğa ilişkin hiçbir ifade etmedi."]],
#   'ref': 'Bir federal yüksek mahkemesinde kendi önceki pozisyonuna karşı açılan hukuki itiraz konusundan hiç bahsetmedi.'},
#  {'src': 'Following a visit to the organization\'s headquarters in Moscow in July, WADA Director General Olivier Niggli stated that RUSADA is "moving in the right direction" to be reinstated.',
#   'candidates': [['Temmuz ayında Moskova merkezine yaptığı ziyaretlerden sonra, WADA Genel Müdürü Oliver Niggli, RUSADA’nın yeniden kurulması için “doğru yöne doğru ilerlediğini” belirtti.'],
#    ['Temmuz ayında Moskova Merkezine yaptığı ziyaretten sonra WADA Genel Direktörü Olivier Niggli, RUSADA’nın yeniden kurulması için “doğru yöne” hareket ettiğini açıkladı.'],
#    ['WADA Genel Müdürü Olivier Niggli, WADA\'nın merkezini Temmuz ayında Moskova\'ya ziyaret ettikten sonra, WADA\'nın yeniden kurulması için "doğru yöne doğru hareket ettiğini" söyledi.'],
#    ['Temmuz ayında Moskova Merkezine yapılan ziyaretten sonra, WADA Genel Direktörü Olivier Niggli, RUSADA\'nın yeniden kurulmasını hedef alan "doğru yönde hareket" olduğunu söyledi.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli, örgütin Moskova merkezini ziyaret ettikten sonra, RUSADA\'nın "doğru yöne" ilerliyor" dedi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli’nin Moskova’da yaptığı ziyareti ardından “RUSADA’nın geri yüklendilmesi için doğru yönde hareket ettiği” belirtildi.'],
#    ['Temmuz ayında Moskova’daki WADA Genel Müdürü Olivier Niggli, RUSADA’nın “doğru yönde hareket ettim” dediğini açıkladı.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli’nin Moskova’daki merkezini ziyaret ettiğinde, RUSADA’nın yeniden kurulması için “doğru yönde hareket ediyor” diyerek açıklamasını yaptı.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayının Moskova merkezini ziyaret ettikten sonra, WADA Genel Müdürü Olivia Niggli, yeniden düzenlenmesi için RUSADA’yı “doğru yöne doğru harekete geçiyor” diyor.'],
#    ['Temmuz ayındaki Moskova merkezine yaptığı ziyarette WADA Genel Müdürü Olivier Niggli, yeniden yerleştirilmesini amaçlayan RUSADA’nın “doğru yöne hareket ediyor” dedi.'],
#    ['Temmuz ayında Moskova\'da bulunan organizasyonun merkezini ziyaret eden WADA Genel Müdürü Olivier Niggli, RUSADA\'nın "doğru yöne doğru hareket ediyor" olarak konuştu.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayında Moskova’daki kuruluşun merkezine yaptığı ziyaretten sonra, WADA’nın yeniden kurulması için “doğru yönde hareket” olduğunu söyledi.'],
#    ['Temmuz ayında, Wada Genel Direktör Olivier Niggli, kuruluşun Moskova merkezine yaptığı ziyaretten sonra, WADA Genel Direktörü Olivier Niggli’nin “doğru yönde hareket ediyor” diyerek yeniden canlandırılması bekleniyor.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA’nın yeniden kurulmak için “doğru yönde hareket ediyor” dedi.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli’in Moskova’daki merkezini ziyaret etmesinden sonra, RUSADA’nın yeniden kurulması için “doğru yönde hareket ediyor” dedi.'],
#    ['Temmuz ayında Moskova’da düzenlenmiş olan kuruluşun merkezini ziyaret ettikten sonra, WADA Genel Müdürü Olivier Niggli, RUSADA’nın yeniden düzenlenmesi için “doğru yöne doğru hareket etmeye çalıştığını” belirtti.'],
#    ['Temmuz ayında Rusya Federasyonu’nun Moskova merkezini ziyaret ettikten sonra, WADA Genel Müdürü Olivier Niggli, RUSADA’nın yeniden kurulması gereken “doğru yönden hareket ediyor” dedi.'],
#    ['Temmuz\'da Rusya\'nın merkezini ziyaret ettikten sonra WADA Genel Müdürü Olivier Niggli, RUSADA\'nın yeniden kurulması için "doğru yönde hareket ediyor" diye konuştu.'],
#    ['Temmuz ayında Moskova\'nın merkezine yaptığı ziyaret sonrasında WADA Genel Direktörü Olivier Niggli "RUSADA\'nın kurulması için doğru yöne gidiyor" dedi.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli, WADA\'nın Moskova\'daki merkezini ziyaret eden RUSADA\'nın geri yüklemek için "doğru yönde hareket ettiğini" belirtti.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayındaki Moskova merkezini ziyaret ettikten sonra RUSADA’nın geri yükleme için “doğru yöne” hareket ettiğini söyledi.'],
#    ['WADA Genel Direktörü Oliver Niggli, Temmuz ayında Moskova\'daki merkezine yaptığı ziyaretten sonra, WADA Genel Direktörü Olivier Niggli\'nin kurulması gereken "doğru yoldan hareket eden" olduğunu belirtti.'],
#    ['Temmuz ayında Moskova’da yapılan bir ziyaretinden sonra, WADA Genel Müdürü Olivier Niggli, yeniden düzenlenmesi amacıyla "doğru yöne doğru hareket ediyor" dedi.'],
#    ['Temmuz ayında Moskova merkezine yaptığı ziyaret sonrasında WADA Genel Direktör Olivier Niggli, RUSADA’nın yeniden yerleştirilmesi gereken “doğru yönde hareket ediyor” dedi.'],
#    ['Temmuz’da WADA Genel Direktörü Olivier Niggli, “RUSADA’nın yeniden düzenlenmesi için doğru yöne doğru hareket gösteriyor” dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’da yapılan bir ziyaret sonrasında WADA’nın yeniden kurulması amacıyla “doğru yönde hareket ediyor” dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki merkezine yaptığı ziyaretten sonra, “RUSADA’nın yeniden kurulduğu doğru yönde hareket ettiğini” söyledi.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayında Moskova’da yaptığı bir ziyaret sonrasında RUSADA’nın yeniden kurulması beklentisi “doğru yönde hareket ediyor”.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA\'nın Moskova\'daki merkezini ziyaret ettikten sonra, RUSADA\'nın yeniden kurulacağını, "doğru yönde hareket ettiğini" belirtti.'],
#    ['Temmuz ayında Moskova’daki merkezini ziyaret ettikten sonra WADA Genel Müdürü Olivier Niggli, RUSADA’nın “doğru yönde” yeniden kurulması gerektiğini söyledi.'],
#    ['Temmuz ayında Moskova\'daki WADA Genel Müdürü Olivier Niggli, RUSADA\'nın "doğru yöne gidiyor" diyor.'],
#    ['Temmuz ayında Moskova’da bulunan bu örgütün merkezini ziyaret ettikten sonra WADA Genel Müdürü Olivier Niggli, RUSADA’nın yeniden kurulması için “doğru yönde hareket ettiğini” belirtti.'],
#    ['Temmuz ayında Wada Genel Müdürü Olivier Niggli, “RUSADA’nın yeniden kurulacağını” söyledi.'],
#    ['Temmuz ayında Moskova’daki merkezine yapılan ziyaretten sonra, WADA Genel Müdürü Olivier Niggli, WADA’nın yeniden yerleştirilmesi gereken “doğru yöne hareket ediyor” dedi.'],
#    ['Temmuz ayında Moskova’daki merkezine ziyaret ettiğinde, WADA Genel Müdürü Olivier Niggli, “RUSADA’nın yeniden yapılandırılması için doğru yöne doğru gidiyor” dedi.'],
#    ['Temmuz’da WADA Genel Müdürü Olivier Niggli’nin, kurtarılması gereken kuruluşun merkezini ziyaret etmesinin ardından RUSADA’nın “doğru yönde hareket etmiyor” diyor.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki merkezine ziyaretten sonra, WADA’nın yeniden kurulması için RUSADA’nın “doğru yönde hareket ettiğini” söyledi.'],
#    ['Temmuz\'da WADA Genel Müdürü Olivier Niggli, RUSADA\'nın geri dönüşü için "doğru yönde" hareket ettiğini söyledi.'],
#    ['Temmuz ayında Moskova’daki kurumsal merkezine yapılan ziyaretden sonra WADA Genel Müdürü Olivier Niggli, RUSADA’nın “doğru yöne doğru hareket ettirildi” dedi.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayında Moskova’ya yaptığı ziyaretten sonra RUSADA’nın yeniden kurulması gereken “doğru yöne” hareket ettiğini belirtti.'],
#    ['Temmuz\'da WADA Genel Direktörü Olivier Niggli, RUSADA\'nın yerleştirilmek üzere "doğru yönde hareket ediyor" diyen bir ziyaretinden sonra Rusya\'nın Moskova\'daki merkezine girdi.'],
#    ['Temmuz\'daki Moskova\'da kurulan kuruluşun merkezi ziyaretinden sonra, WADA Genel Müdürü Olivier Niggli, yeniden kurulması amacıyla RUSADA\'nın "doğru yönde" hareket ettiğini ifade etti.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki kuruluşun merkezini ziyaret ettikten sonra “RUSADA’nın yeniden kurulması için doğru yöne gidiyor” diye konuştu.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli, kurulmasını amaçlayan “doğru yöne hareket” ettiğini açıkladı.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova\'daki merkezine yaptığı ziyaretten sonra, WADA\'nın yeniden yerleştirilmesi için RUSADA\'nın "doğru yönde hareketli olduğunu" belirtti.'],
#    ['Temmuz ayında Rusya’nın başkentine yaptığı ziyaret sonrasında Wada Genel Direktörü Olivier Niggli, yeniden kurulması için “doğru yöne doğru hareket ediyor” diyor.'],
#    ["Temmuz ayında Moskova'daki kurumun merkezine yaptığı ziyaretden sonra WADA Genel Müdür Olivier Niggli, RUSADA'nın yeniden yerleştirilmesi için “doğru yöne hareket ettiğini” ifade etti."],
#    ['WADA Genel Direktörü Olivier Niggli, WADA’nın Temmuz ayında Moskova’nın merkezine yaptığı ziyaretden sonra RUSADA’nın geri yüklemek için “doğru yöne hareket ettiğini” ifade etti.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz’da Moskova merkezini ziyaret ettikten sonra, “RUSADA’nın yeniden kurulduğu doğru yöndeki hareketlerde olduğunu” söyledi.'],
#    ['WADA Genel Başkanı Olivier Niggli, bu konuda "doğru yöne gidiyor" dedi.'],
#    ['Temmuz ayında Rusya\'nın merkezine yaptığı ziyaret sonrasında, WADA Genel Direktörü Olivier Niggli, RUSADA\'nın "doğru yönde hareket" olduğunu söyledi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, "RUSADA\'nın yeniden kurulumu için doğru yönde hareket ettiğini" belirtti.'],
#    ['Temmuz ayında, WADA Genel Müdürü Olivier Niggli, örgütün Moskova merkezini ziyaret ettikten sonra, RUSADA\'nın yeniden kurulacağı için "doğru yöne" hareket ediyor olduğunu açıkladı.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayının başında Moskova’daki bir ziyaret sonrasında, RUSADA’nın yeniden kurulması için “doğru yönde hareket ediyor” diyerek, WADA Genel Müdürü Olive Niggli’nin yaptığı görüşmeyi dile getirdi.'],
#    ['Temmuz ayında WADA Genel Başkanı Olivier Niggli\'nin Moskova\'daki merkezini ziyaret ettikten sonra, WADA Genel Müdürü Olivier Niggli\'nin yeniden kurulması için "doğru yönde hareket ediyor" diyen RUSADA\'yı duyurdu.'],
#    ['Temmuz ayında Moskova\'da düzenlenecek toplantıdan sonra WADA Genel Direktörü Olivier Niggli, WADA\'nın yeniden kurulmasını amaçlayan "doğru yönde hareket" olduğunu belirtti.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova merkezini ziyaret ederek, WADA Genel Müdürü Olivier Niggli, WADA\'nın yeniden kurulması amacıyla "sağlıklı yönde" hareket ettiğini açıkladı.'],
#    ['Temmuz ayında Moskova\'da düzenlenen ziyaretden sonra WADA Genel Müdürü Olivier Niggli, WADA\'nın yeniden kurulması için "doğru yönde" hareket ettiğini açıkladı.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli\'nin Moskova merkezine yaptığı ziyaret üzerine, RUSADA\'nın yeniden kurulması için "doğru yönde hareket etti" dedi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, örgütün Moskova merkezine yaptığı ziyaret sonrasında, kurulması için RUSADA\'nın "doğru yöne doğru ilerliyor" dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova merkezini ziyaret ettikten sonra WADA Genel Müdürünü, RUSADA’nın yeniden kurulacak şekilde “doğru yönde hareket ettiğini” belirtti.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, "RUSADA\'yı yeniden inşa etmek için doğru yöne doğru yürüyor" dedi.'],
#    ["Temmuz ayında WADA Genel Müdürü Olivier Niggli, RUSADA'nın “doğru yöne doğru hareket ediyor” dedi."],
#    ['WADA Genel Müdürü Olivier Niggli, WADA Genel Müdürlüğü’nün Temmuz ayında Moskova’daki merkezinde yaptığı ziyaretten sonra, WADA’nın yeniden kurulması amacıyla “doğru yöne doğru hareket ediyor” diyerek, bir açıklamayı verdi.'],
#    ['Temmuz ayında Moskova merkezine gelen ziyaret sonrasında WADA Genel Müdürü Oliver Niggli, “RUSADA’nın yeniden kurulacak yönde hareket ettirildiğini” söyledi.'],
#    ['Temmuz ayında Moskova’daki örgütün merkezine yapılan ziyaretten sonra WADA Genel Müdürü Olivier Niggli, RUSADA’nın kurulması için “doğru yöne doğru ilerlemektedir” dedi.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayında Moskova merkezini ziyaret ettikten sonra, WADA Genel Direktörü Olivier Niggli, RUSADA’nın yeniden kurulması için “doğru yöne doğru hareket ettiğini” belirtti.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA’nın Moskova’ya yaptığı ziyaretin ardından, WADA’nın yeniden kurulması için “doğru yöne gidiyor” dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova Merkezine yaptığı ziyaret sonrasında, WADA’nın yeniden düzenlenmesi için RUSADA’nın “doğru yöne gittiklerini” belirtti.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki merkezine yapılan ziyaretin ardından, “RUSADA’nın yeniden kurulması için doğru yöne doğru hareket ettiğini” belirtti.'],
#    ['Temmuz ayında Moskova\'nın başkentiyle yaptığı ziyaret sonrasında, WADA Genel Direktörü Olivier Niggli, WADA\'nın yeniden kurulması için "doğru yönde" hareket ettiğini söyledi.'],
#    ['Temmuz ayında, WADA Genel Direktörü Olivier Niggli, RUSADA’nın “doğru yöne hareket etmeye” gitmesini talep ettiğini söyledi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki kuruluşun merkezi ziyaretinden sonra, “RUSADA’nın kurulması için doğru yola doğru hareket ettiğini” açıkladı.'],
#    ['Temmuz\'da WADA Genel Direktörü Olivier Niggli\'in Moskova merkezine yaptığı ziyaretten sonra, "RUSADA\'nın kurulacak doğru yönde hareket ettiği" açıklandı.'],
#    ['WADA Genel Müdürü Olivier Niggli, WADA\'nın Moskova merkezine Temmuz ayında yaptığı bir ziyaretten sonra, WADA Genel Müdürü Olivier Niggli\'nin yeniden kurulması için "doğru yöne" hareket ettiğini söyledi.'],
#    ['Temmuz ayında Moskova\'daki merkezine bir ziyaret sonrasında WADA Genel Müdürü Olivier Niggli, WADA\'nın yeniden kurulması için "doğru yönde hareketli" olduğunu belirtti.'],
#    ['WADA Genel Direktörü Olivier Niggli, organizasyonun Moskova merkezine yaptığı bir ziyaret sonrasında, WADA Genel Başkanı Olivier Niggli\'nin "doğru yönde hareket ettiğini" söyledi.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli tarafından Moskova merkezini ziyaret ettikten sonra, WADA\'nın "doğru yöne doğru hareket ettirdiğini" söyledi.'],
#    ['WADA Genel Müdürü Olivier Niggli, WADA’nın Temmuz ayında Moskova Merkezine yaptığı ziyaretinden sonra, WADA’nın yeniden kurulması için “doğru yöne doğru ilerliyor” dedi.'],
#    ['Temmuz ayında, WADA Genel Direktörü Olivier Niggli, organizasyona Moskova’da bulunan merkezine ziyaretinin ardından, “RUSADA’nın yeniden kurulması için doğru yönde hareketli olduğunu” belirtti.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA\'nın Moskova\'daki merkezine yaptığı ziyaret sonrasında, kurulumu sağlamak için "doğru yöne" hareket ettiğini belirtti.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, organizasyona gelen Moskova merkezini ziyaret ettiğini ve “doğru yönden hareketli” olduğunu belirtti.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli, organizasyonun Moskova merkezine yaptığı bir ziyaret sonucunda, WADA\'nın yeniden kurulması için "doğru yönde hareket" olduğunu söyledi.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayında Moskova’ya gelen ziyaretinde, RUSADA’nın yeniden kurulması için “doğru yöne hareket” yaptığını belirtti.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayında Moskova’daki merkezini ziyaret ettiği sırada, “RUSADA’nın yeniden kurulması için doğru yöne geçiyor” dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki bir ziyaret sonrasında, WADA’nın geri dönüştürülmesi için “doğru yöne gidiyor” dedi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, organizasyonun Moskova merkezini ziyaret ettikten sonra, “RUSADA’nın yeniden kurulacağı” anlamına geliyor.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki merkezini ziyaret ettikten sonra WADA’nın yeniden kurulması için “doğru yöne” ilerlediğini belirtti.'],
#    ['Temmuz ayında Rusya\'nın Moskova merkezine yaptığı ziyaretten sonra, WADA Genel Direktörü Olivier Niggli, RUSADA\'nın "doğru yönde hareket ettiğini" belirtti.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, organizasyonun Moskova merkezini ziyaret ettikten sonra, RUSADA\'nın yeniden kurulması için "doğru yönde hareket ediyor" dedi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA’nın Rusya’ya geri dönmesi için “doğru yöne” hareket ediyor olduğunu söyledi.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli, kurulmasının yeniden kurulması için “doğru yönde hareket ediyor” dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, WADA’nın merkezine Moskova’da yaptığı ziyaretinden sonra, WADA’nın “doğru yöne gidiyor” dedi.'],
#    ['Temmuz ayında Moskova’daki merkezine yapılan ziyaretlerden sonra WADA Genel Müdürü Olivier Niggli, RUSADA’nın yeniden yerleştirilmesine yönelik “sağ yöne hareket ediyor” dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli’nin Temmuz ayında Moskova’da yaptığı bir ziyaretin ardından RUSADA’nın yeniden kurulacağı “doğru yöne” gideceğini söyledi.'],
#    ["Temmuz ayının Moskova merkezini ziyaret eden WADA Genel Müdürü Olivier Niggli, RUSADA'nın yeniden kurulacak yönde hareket ediyor olduğunu açıkladı."],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA’nın Moskova merkezine yaptığı ziyaret sonrasında, RUSADA’nın yeniden kurulması için “doğru yönde hareket edip” olduğunu belirtti.'],
#    ["Temmuz ayında Moskova'daki kuruluşun merkezine yaptığı ziyaret sonrasında, WADA Genel Müdürü Olivier Niggli, yeniden kurulacağı “doğru yöne” hareket ettiğini söylemişti."],
#    ['Temmuz\'da WADA Genel Müdürü Olivier Niggli, WADA\'nın Moskova merkezine yaptığı ziyareti ardından WADA\'nın yeniden kurulması için "doğru yöne hareket ediyor" dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, WADA’nın Temmuz ayında Moskova’daki merkezini ziyaret ettikten sonra, WADA’nın yeniden düzenlenmesi gereken “doğru yönde harekete geçiyor” diyerek bu konuda “doğru yönde” çalıştığını açıkladı.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA’nın kurulması için “doğru yöne doğru hareket ettirildiğini” bildirdi.'],
#    ["Temmuz ayında WADA Genel Direktör Oliver Niggli, kuruluşun merkezini Moskova'ya ziyaret ettikten sonra WADA Genel Müdürlüğü, RUSADA'nın yeniden kurulması için 'doğru yöne hareket' olduğunu söyledi."],
#    ["Temmuz ayında Rusya'nın Moskova merkezine yapılan ziyaretinden sonra WADA Genel Müdürü Olivier Niggli, RUSADA'nın yeniden kurulacağı yolda ilerlediğini söyledi."],
#    ['Temmuz ayında Moskova’da yaptığı ziyaretin ardından WADA Genel Direktörü Olivier Niggli, RUSADA’nın yeniden kurulacağı doğru yönde hareket ettiğini belirtti.'],
#    ['Temmuz ayında Moskova’da yaptığı ziyareti takip eden WADA Genel Müdürü Olivier Niggli, RUSADA’nın yeniden kurulması için “doğru yöne hareket ediyor” diyor.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli\'nin Moskova Merkezine yaptığı ziyaretten sonra, RUSADA\'nın yeniden kurulması için "doğru yönde hareket" olduğunu belirtti.'],
#    ['Temmuz ayında Rusya Federasyonu’nun Moskova merkezine yaptığı ziyaretten sonra WADA Genel Direktörü Olivier Niggli, WADA’yı “doğru yöne doğru hareket ediyor” diyerek kurtulma kararını verdi.'],
#    ['Temmuz ayında Rusya’nın Moskova merkezini ziyaret ettiği sırada, WADA Genel Direktörü Olivier Niggli “doğru yönde hareket eden” olduğunu ifade etti.'],
#    ['Temmuz ayında Moskova merkezinde yaptığı ziyaretten sonra WADA Genel Müdürü Olivier Niggli, “RUSADA’yı geri getirmek için doğru yönde hareket ediyor” dedi.'],
#    ['Temmuz ayında Moskova merkezine yaptığı ziyaretten sonra WADA Genel Direktörü Olivier Niggli, “RUSADA’nın yeniden kurulması için doğru yöne hareket ediyor” dedi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, WADA’nın Moskova merkezine yaptığı ziyaretin ardından “doğru yönde hareket ediyor” dedi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, "RUSADA\'nın yeniden kurulması için doğru yönde yürümeye hazır" olduğunu bildirdi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova\'daki merkez ziyaretinden sonra, RUSADA\'nın "doğru yöne hareket ediyor" diye açıklandı.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz aylarında Moskova’daki merkezine bir ziyaret yaptıktan sonra, WADA Genel Müdürü Olivier Niggli, yeniden düzenlenmesi amacıyla RUSADA’nın “doğru yöne doğru hareket ettiğini” belirtti.'],
#    ['Temmuz ayında WADA Genel Direktörü Olivier Niggli, RUSADA\'nın yeniden kurulması amacıyla "doğru yöne gitmesi" konusunda yaptığı açıklamada, "Moskova\'nın Moskova merkezini ziyaret ettikten sonra.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli, kuruluşun merkezini Moskova’ya ziyaret ettikten sonra, kurulması gereken RUSADA’nın “doğru yöne hareket ediyor” dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki merkezlerine yapılan bir ziyarete göre, WADA’nın kurulması gereken “doğru yöne hareket ettiğini” belirtti.'],
#    ['WADA Genel Müdürlüğü\'nün Temmuz ayında Moskova\'da yaptığı bir ziyarette yaptığı açıklamada, WADA Genel Direktörü Olivier Niggli "Düz yönde hareket ettirmeye" gidiyor.'],
#    ['WADA Genel Müdürü Olivier Niggli Temmuz ayında Moskova’daki merkezine yaptığı ziyaret ardından, RUSADA’nın yeniden kurulacak “doğru yöne doğru hareket ettik” dedi.'],
#    ['Temmuz ayında Wada Genel Müdürü Olivier Niggli\'nin Moskova\'daki merkezine yaptığı ziyarette, Wada\'nın yeniden kurulması için "doğru yöne doğru hareket" olduğunu belirtti.'],
#    ['Temmuz ayında Moskova’da yaptığı ziyaretten sonra WADA Genel Direktörü Olivier Niggli, RUSADA’nın “doğru yöne doğru hareket ettiği” iddia etti.'],
#    ['Temmuz’da WADA Genel Müdürü Olivier Niggli, kuruluşun Moskova’daki merkezini ziyaret ettikten sonra, WADA’nın yeniden yerleştirilmesi için “doğru yöne gitmeye” başladığını açıkladı.'],
#    ['WADA Genel Direktörü Olivier Niggli, Temmuz ayında Moskova’da yapılan bir ziyaret sonrasında, RUSADA’nın yeniden kurulması gereken “doğru yönde” çalıştığını söyledi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova merkezine ziyaret ettiğinde, WADA\'nın yeniden kurulmasını amaçlayan "doğru yöne" hareket ettiğini söyledi.'],
#    ['Temmuz ayında WADA Genel Müdürü Olivier Niggli’nin Moskova’daki merkezini ziyaret etmesine göre, WADA’nın yeniden kurulması için RUSADA ‘doğru yöne gidiyor’ dedi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova’daki merkezini ziyaret ettiği için, WADA’nın yeniden kurulmak için “doğru yönde hareket ettiğini” söyledi.'],
#    ['WADA Genel Müdürü Olivier Niggli, Temmuz ayında Moskova merkezine yaptığı ziyarete ardından WADA’nın yeniden kurulması için “doğru yöne doğru hareket ettiğini” açıkladı.'],
#    ['Temmuz ayında Moskova’daki merkezine yaptığı ziyaret sonrasında WADA Genel Direktörü Olivier Niggli, “RUSADA’nın yeniden kurulması için doğru yöne hareket etmektedir” dedi.']],
#   'ref': 'Temmuzda, kurumun Moskova\'daki genel merkezine yapılan bir ziyaretin ardından WADA Direktörü Olivier Niggli RUSADA\'nın yeniden işler hale gelmek için "doğru yönde ilerlediğini" açıklamıştı.'},
#  {'src': 'And true leadership means accepting that.',
#   'candidates': [['Ve gerçek liderlik bunun kabul edilmesi anlamına gelir.'],
#    ['Gerçek liderlik bunu kabul etmektir.'],
#    ['Gerçek liderlik ise bunu kabul etmektir.'],
#    ['Gerçek liderlik bunu kabul etmektir.'],
#    ['Doğru liderlik buna katılmak anlamına gelir.'],
#    ['Bir liderlik bu kabul anlamına gelir.'],
#    ['Gerçek bir liderlik, bunu kabul etmektir.'],
#    ['Gerçek bir liderlik bunu kabul eder.'],
#    ['Ve gerçek liderlik bunu kabul etmektir.'],
#    ['Gerçek yönetimi bu anlamda kabul etmenin anlamıdır.'],
#    ['Gerçek bir liderlik bunu kabul etmeyi amaçlıyor.'],
#    ['Gerçek liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek bir liderlik bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik demektir, bunu kabul etmek.'],
#    ['Gerçek liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek anlamına geliyor.'],
#    ['Ve gerçek liderlik, bunu kabul etmeyi demektir.'],
#    ['Gerçek liderlik demektir bunun için.'],
#    ['Gerçek bir liderlik bunu kabul etmek demektir.'],
#    ['Gerçek liderlik bunun kabul edilmesidir.'],
#    ['Ama gerçek liderlik anlamına gelir bunu kabul etmek.'],
#    ['Gerçek bir liderlik ise bunu kabul etmektir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek bir liderlik de buna katılmak anlamına gelir.'],
#    ['Gerçek liderlik, bunu kabul etmeyi anlamına gelir.'],
#    ['Gerçek bir liderlik ise bunu kabul etmektir.'],
#    ['Gerçek bir liderlik bunun kabulü demektir.'],
#    ['Gerçek liderlik bu anlamda kabul edilir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek demektir.'],
#    ['Ama gerçek liderlik bunları kabul ettirme anlamına gelir.'],
#    ['Gerçek liderlik bunu kabul etmek anlamına gelir.'],
#    ['Ama gerçek bir liderlik buna bağlı olmak demektir.'],
#    ['Gerçek liderlik bunu kabul etmektir.'],
#    ['Gerçek liderlik bunu kabul etmektir.'],
#    ['Ve gerçekten liderlik, kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik bunu kabul etmektir.'],
#    ['Ve gerçek liderlik bunun kabul edilmesini anlamaktadır.'],
#    ['Doğru liderlik bunu kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik bunu kabul etmek anlamına gelir.'],
#    ['Gerçek bir liderlik bu anlamına gelir.'],
#    ['Gerçek liderlik, buna izin vermek demektir.'],
#    ['Gerçek liderlik de bunu kabul etmek demektir.'],
#    ['Bir gerçek liderlik ise bu anlamda kabul etmektir.'],
#    ['Doğru liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek bir liderlik de bunu kabul etmektedir.'],
#    ['Gerçek liderlik, bunu kabul etmek anlamına geliyor.'],
#    ['Gerçek liderlik bunu kabul etmeyi amaçlıyor.'],
#    ['Ve gerçek liderlik, bunu kabul etmenin anlamına gelir.'],
#    ['Gerçek bir liderlik demek de bunu kabul etmektir.'],
#    ['Doğru liderlik bunu kabul etmek demektir.'],
#    ['Gerçek liderlik, bu şeye katılmak anlamına gelir.'],
#    ['Gerçek bir liderlik ise bunu kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik ise bunu kabul etmek demektir.'],
#    ['Gerçek bir yönetim, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik buna karşılık vermek demektir.'],
#    ['Gerçek bir liderlik bu konuda kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Ve gerçek bir liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek liderlik bunu kabul etmektir.'],
#    ['Gerçek liderlik bunun kabul edilmesidir.'],
#    ['Gerçek liderlik bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek yönetim, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik bunu kabul etmek demektir.'],
#    ['Gerçek liderlik ise bunu kabul etmek demektir.'],
#    ['Gerçek liderlik bunu kabul etmek demektir.'],
#    ['Ve gerçek liderlik bunu kabul etmek demektir.'],
#    ['Bir lider olmak bunun anlamına geliyor.'],
#    ['Ve gerçek bir liderlik anlamına gelir bunu kabul etmektir.'],
#    ['Ama gerçek bir liderlik bunu kabul etmektir.'],
#    ['Gerçek bir liderlik bunu kabul etmenin anlamıdır.'],
#    ['Gerçek bir liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik, kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik bunu kabul etmek demektir.'],
#    ['Ve gerçek liderlik bunun kabul edilmesini ifade etmektedir.'],
#    ['Ve gerçek liderlik anlamına gelir bunu kabul etmek.'],
#    ['Ama gerçek liderlik bunu kabul etmektedir.'],
#    ['Doğru liderlik bunun anlamını da anlamaktadır.'],
#    ['Ve gerçek liderlik demek, bunu kabul etmektir.'],
#    ['Gerçek bir yönetim bunu kabul etmeyi ifade eder.'],
#    ['Ve gerçek bir liderlik bunun kabul edilmesini sağlar.'],
#    ['Gerçek bir liderlik, bunu kabul etmeyi ifade eder.'],
#    ['Gerçek bir liderlik bunu kabul etmek demektir.'],
#    ['Ve gerçek liderlik, bunu kabul etmeyi işaret ediyor.'],
#    ['Gerçek bir yönetim anlamı bunu kabul etmektir.'],
#    ['Bu anlamda gerçek liderlik bunu kabul etmeyi ifade ediyor.'],
#    ['Gerçek liderlik, bunun farkında olmak demektir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik ise bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik bunun kabulü anlamına geliyor.'],
#    ['Gerçek liderlik, bunu kabul etmeyi ifade ediyor.'],
#    ['Gerçek liderlik bunu kabul eder.'],
#    ['Gerçek bir liderlik, bunu kabul etmektir.'],
#    ['Gerçek liderlik bunun kabul edilmesini içeren bir önlem.'],
#    ['Gerçek yönetim, bunun kabul edilmesine anlamaktadır.'],
#    ['Gerçek bir liderlik, bunu kabul etmeyi amaçlamaktadır.'],
#    ['Gerçek bir liderlik bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik demek, kabul etmektir.'],
#    ['Gerçek bir yönetim bunun kabul edilmesidir.'],
#    ['Doğru liderlik bunun anlamını kabul etmektedir.'],
#    ['Ve gerçek liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek liderlik de bunu kabul etmek demektir.'],
#    ['Gerçek bir yönetim bunun kabul edilmesini anlamına gelir.'],
#    ['Gerçek bir liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek bir liderlik ise bunu kabul etmeyi anlamaktadır.'],
#    ['Gerçek yönetim ise bunun anlamına geliyor.'],
#    ['Ve doğru liderlik bunu kabul etmek demektir.'],
#    ['Gerçek bir liderlik demektir bunu kabul etmektir.'],
#    ['Gerçek bir yönetim, buna sahip olmak demektir.'],
#    ['Ve gerçek bir liderlik, buna izin vermek anlamına gelir.'],
#    ['Gerçek liderlik, bunu kabul etmek anlamına gelir.'],
#    ['Gerçek yönetimi bunun kabul edilmesini amaçlamaktadır.'],
#    ['Gerçek liderlik, bunu kabul etmenin anlamıdır.'],
#    ['Gerçek bir liderlik anlamına gelir bunu kabul etmektir.'],
#    ['Gerçek liderlik bunun farkına varmak demektir.'],
#    ['Ve gerçek liderlik bunu kabul etmek demektir.'],
#    ['Doğru liderlik ise bunu kabul etmektir.'],
#    ['Gerçek bir liderlik demek bu işe sahip olmak demektir.'],
#    ['Gerçek bir liderlik buna karşılık getirecektir.'],
#    ['Gerçek bir liderlik bu durumu kabul etmek demektir.'],
#    ['Ve gerçek bir liderlik bunu kabul etmenin anlamını ifade eder.'],
#    ['Ve gerçek bir liderlik bunun kabul edilmesi anlamına gelir.'],
#    ['Gerçek liderlik ise bu durumu kabul etmek demektir.']],
#   'ref': 'Gerçek liderlik de bunu kabul etmek anlamına geliyor.'}]
