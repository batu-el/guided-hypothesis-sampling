# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
drive_PATH = '../content/drive/MyDrive/Colab Notebooks/l101.experiments.1'
# Out:
# Mounted at /content/drive

# %%
# !pip install jsonlines scikit-optimize
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.3.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-23.12.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.23.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.2.0)
# Installing collected packages: pyaml, jsonlines, scikit-optimize
# Successfully installed jsonlines-4.0.0 pyaml-23.12.0 scikit-optimize-0.9.0

# %%
import jsonlines

# DATA_NAME = 'DEEN'
# DATA_NAME = 'ENDE'
DATA_NAME = 'ENTR'
# DATA_NAME = 'TREN'
DATA_PATH = drive_PATH + f'/data-main/{DATA_NAME}.jsonl'
DATA = []
with jsonlines.open(DATA_PATH) as f:
    for line in f.iter():
        DATA.append(line)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import tqdm
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns
import random
import sys

# %%
num_datapoints = 1000
reduced_dim = 10

# %%
# Encoded Data
enc_candidates = []
enc_candidates10 = []
# Scores
BLEURT_cand_scores = []
CHRF_cand_scores = []
# chrF++ Scores
MBR_BLEURT_cand_scores = []
MBR_CHRF_cand_scores = []
# Winner Indexes
MBR_BLEURT_winner_index = []
MBR_CHRF_winner_index = []
# Blackbox Functions
enc10_to_idx = []
enc10_to_MBR_BLEURT = []
enc10_to_MBR_CHRF = []
# Rankings
MBR_BLEURT_index_rank = []
MBR_CHRF_index_rank = []

for idx in tqdm.tqdm(range(num_datapoints)):
    idx_datapoint = DATA[idx]

    # Encoded Data
    _enc_data = np.array(idx_datapoint['enc_candidates'])
    enc_candidates.append(_enc_data)
    pca = PCA()
    _enc_data_10 = pca.fit_transform(_enc_data)[:,:reduced_dim]
    enc_candidates10.append(_enc_data_10)

    # Scores
    _bleurt_scores = np.array([np.round(score, 6)-0.5 for score in idx_datapoint['BLEURT_cand_scores']])
    _chrf_scores = np.array([np.round(score, 6)-50 for score in idx_datapoint['CHRF_cand_scores']])
    BLEURT_cand_scores.append(_bleurt_scores)
    CHRF_cand_scores.append(_chrf_scores)

    # MBR Scores
    _mbr_bleurt_scores = np.array([np.round(score, 6) for score in idx_datapoint['MBR_BLEURT_cand_scores']])/128 -0.5
    _mbr_chrf_scores = np.array([np.round(score, 6) for score in idx_datapoint['MBR_CHRF_cand_scores']])/128 -50
    MBR_BLEURT_cand_scores.append(_mbr_bleurt_scores)
    MBR_CHRF_cand_scores.append(_mbr_chrf_scores)

    # Winner Indexes
    _mbr_bleurt_winner_idx = idx_datapoint['MBR_BLEURT_winner_index']
    _mbr_chrf_winner_idx = idx_datapoint['MBR_CHRF_winner_index']
    MBR_BLEURT_winner_index.append(_mbr_bleurt_winner_idx)
    MBR_CHRF_winner_index.append(_mbr_chrf_winner_idx)

    # Blackbox Function : Uses Negative Utility = Risk
    _enc10_to_idx = {str(_enc_data_10[i]): i for i in range(128)}
    _enc10_to_MBR_BLEURT = {str(enc10):_mbr_bleurt_scores[_enc10_to_idx[str(enc10)]] for enc10 in _enc10_to_idx.keys()}
    _enc10_to_MBR_chrF = {str(enc10):_mbr_chrf_scores[_enc10_to_idx[str(enc10)]] for enc10 in _enc10_to_idx.keys()}

    enc10_to_idx.append(_enc10_to_idx)
    enc10_to_MBR_BLEURT.append(_enc10_to_MBR_BLEURT)
    enc10_to_MBR_CHRF.append(_enc10_to_MBR_chrF)

    # Rankings
    _MBR_BLEURT_index_rank = ss.rankdata(_mbr_bleurt_scores)
    _MBR_CHRF_index_rank = ss.rankdata(_mbr_chrf_scores)
    MBR_BLEURT_index_rank.append(_MBR_BLEURT_index_rank)
    MBR_CHRF_index_rank.append(_MBR_CHRF_index_rank)

enc_candidates = np.array(enc_candidates)
enc_candidates10 = np.array(enc_candidates10)
BLEURT_cand_scores = np.array(BLEURT_cand_scores)
CHRF_cand_scores = np.array(CHRF_cand_scores)
MBR_BLEURT_cand_scores = np.array(MBR_BLEURT_cand_scores)
MBR_CHRF_cand_scores = np.array(MBR_CHRF_cand_scores)
MBR_BLEURT_winner_index = np.array(MBR_BLEURT_winner_index)
MBR_CHRF_winner_index = np.array(MBR_CHRF_winner_index)
### Blackbox Function Example Usage
# enc10_to_MBR_chrF[0][str(enc_candidates10[0][0])]
# Out:
# 100%|██████████| 1000/1000 [01:52<00:00,  8.93it/s]

# %%
from skopt.learning import GaussianProcessRegressor
from skopt.space import Space
from skopt.acquisition import gaussian_ei
from sklearn.gaussian_process.kernels import RBF, ConstantKernel, WhiteKernel
import numpy as np

from scipy.stats import norm

np.random.seed(1)

# %%
BASELINE_best_MBR_CHRF = []
BASELINE_best_MBR_CHRF_rank = []
BASELINE_best_CHRF = []

MODEL_best_MBR_CHRF = []
MODEL_best_MBR_CHRF_rank = []
MODEL_best_CHRF = []

for experiment in range(10):
    for idx in tqdm.tqdm(range(1000)):
        # CHRF
        X = enc_candidates10[idx]
        y = MBR_CHRF_cand_scores[idx]
        f = enc10_to_MBR_CHRF[idx]

        #######################
        ### Random Baseline ###
        #######################
        n_samples = 10
        initial_indices = np.random.choice(range(len(X)), n_samples, replace=False)
        initial_samples = X[initial_indices]
        initial_evaluations = [f[str(x)] for x in initial_samples]
        best_index_local = np.argmax(initial_evaluations)
        best_index = initial_indices[best_index_local]
        # Results
        best_MBR_CHRF = MBR_CHRF_cand_scores[idx][best_index]
        best_MBR_CHRF_rank = MBR_CHRF_index_rank[idx][best_index]
        best_CHRF = CHRF_cand_scores[idx][best_index]
        # print("Baseline - best_MBR_CHRF:", best_MBR_CHRF)
        # print("Baseline - best_MBR_CHRF_rank:", best_MBR_CHRF_rank)
        # print("Baseline - best_CHRF:", best_CHRF)
        BASELINE_best_MBR_CHRF.append(best_MBR_CHRF)
        BASELINE_best_MBR_CHRF_rank.append(best_MBR_CHRF_rank)
        BASELINE_best_CHRF.append(best_CHRF)
        #####################################################################################
        ### Bayesian Optimization with Gaussian Process Regression - Expected Improvement ###
        #####################################################################################
        n_initial_points = 5
        num_iterations = 5
        initial_indices = np.random.choice(range(len(X)), n_initial_points, replace=False)
        initial_samples = X[initial_indices]
        initial_evaluations = [f[str(x)] for x in initial_samples]
        # GP model
        kernel = ConstantKernel(constant_value=1.0) * RBF(length_scale=1.0)
        gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=5 , normalize_y =False,  alpha=0.00001)
        # Train GP Model
        gp.fit(initial_samples, initial_evaluations)

        for _ in range(num_iterations):
            # Current best
            current_best = np.max(gp.y_train_)
            # Acquisition values
            acquisition_values = - gaussian_ei(X, gp, y_opt=current_best, xi=0.01)
            # acquisition_values = np.zeros([128]) # Random Baseline
            # Filter out previously evaluated points
            evaluated_points = set(map(tuple, gp.X_train_))
            filtered_acquisition = np.array([acq if tuple(point) not in evaluated_points else -np.inf for point, acq in zip(X, acquisition_values)])
            ##########################
            # Select the next index (Alternative 1)
            # next_index = np.argmax(filtered_acquisition)
            # Select the next index (Alternative 2)
            p_current = n_initial_points + _ + 100   # Filter out smallest elements p elements
            smallest_ten_indices = np.argsort(filtered_acquisition)[:p_current]
            for index in smallest_ten_indices:
                filtered_acquisition[index] = float('-inf')
            valid_indices = [index for index, value in enumerate(filtered_acquisition) if value != float('-inf')] # indices whose corresponding elements are not -inf
            next_index = random.choice(valid_indices) #  sample an index from the valid indices
            ##########################
            # Select the next point
            next_point = X[next_index]
            # Evaluate the next point
            next_evaluation = f[str(next_point)]
            # Train GP model including the new point
            X_new = np.vstack([gp.X_train_, next_point])
            Y_new = np.append(gp.y_train_, next_evaluation)
            gp.fit(X_new,Y_new)

        # Results
        best_evaluation_index_local = np.argmax(gp.y_train_)
        best_point = gp.X_train_[best_evaluation_index_local]
        best_value = gp.y_train_[best_evaluation_index_local]
        best_evaluation_index = enc10_to_idx[idx][str(best_point)]
        best_MBR_CHRF = MBR_CHRF_cand_scores[idx][best_evaluation_index]
        best_MBR_CHRF_rank = MBR_CHRF_index_rank[idx][best_evaluation_index]
        best_CHRF = CHRF_cand_scores[idx][best_evaluation_index]
        # print("Model best_MBR_CHRF:", best_MBR_CHRF)
        # print("Model best_MBR_CHRF_rank:", best_MBR_CHRF_rank)
        # print("Model best_CHRF:", best_CHRF)
        MODEL_best_MBR_CHRF.append(best_MBR_CHRF)
        MODEL_best_MBR_CHRF_rank.append(best_MBR_CHRF_rank)
        MODEL_best_CHRF.append(best_CHRF)
        # print('---')
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 100%|█████████▉| 999/1000 [10:55<00:00,  1.57it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 100%|██████████| 1000/1000 [10:55<00:00,  1.52it/s]
#   0%|          | 1/1000 [00:00<11:18,  1.47it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   0%|          | 4/1000 [00:02<12:08,  1.37it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   1%|          | 9/1000 [00:06<11:15,  1.47it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   1%|          | 10/1000 [00:06<10:49,  1.52it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   1%|          | 12/1000 [00:08<10:47,  1.53it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   1%|▏         | 14/1000 [00:09<10:57,  1.50it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   2%|▏         | 21/1000 [00:14<10:54,  1.50it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   2%|▏         | 22/1000 [00:14<11:15,  1.45it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   3%|▎         | 29/1000 [00:19<11:00,  1.47it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   3%|▎         | 30/1000 [00:20<10:51,  1.49it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   3%|▎         | 33/1000 [00:22<10:29,  1.54it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   5%|▍         | 46/1000 [00:30<10:36,  1.50it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   5%|▍         | 48/1000 [00:31<11:02,  1.44it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   5%|▌         | 50/1000 [00:33<11:03,  1.43it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#   5%|▌         | 51/1000 [00:33<11:33,  1.37it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   6%|▌         | 58/1000 [00:38<10:01,  1.57it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   8%|▊         | 75/1000 [00:50<10:54,  1.41it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   8%|▊         | 81/1000 [00:54<10:41,  1.43it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   9%|▊         | 86/1000 [00:57<10:05,  1.51it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#   9%|▊         | 87/1000 [00:58<09:46,  1.56it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#   9%|▉         | 91/1000 [01:01<10:35,  1.43it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  10%|▉         | 96/1000 [01:04<10:18,  1.46it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  10%|▉         | 97/1000 [01:05<09:55,  1.52it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  11%|█         | 106/1000 [01:11<10:08,  1.47it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  11%|█         | 110/1000 [01:14<09:56,  1.49it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  11%|█         | 112/1000 [01:15<10:06,  1.46it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  11%|█▏        | 113/1000 [01:16<10:09,  1.45it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  12%|█▏        | 116/1000 [01:18<10:19,  1.43it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#  92%|█████████▏| 918/1000 [10:11<00:53,  1.53it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  92%|█████████▎| 925/1000 [10:16<00:47,  1.58it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  93%|█████████▎| 933/1000 [10:21<00:49,  1.35it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#  94%|█████████▎| 936/1000 [10:24<00:44,  1.45it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  94%|█████████▍| 944/1000 [10:29<00:40,  1.39it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  95%|█████████▍| 949/1000 [10:33<00:35,  1.43it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  95%|█████████▌| 950/1000 [10:33<00:35,  1.40it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  96%|█████████▌| 959/1000 [10:41<00:31,  1.30it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  96%|█████████▋| 963/1000 [10:44<00:26,  1.37it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  97%|█████████▋| 970/1000 [10:49<00:21,  1.37it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  97%|█████████▋| 972/1000 [10:50<00:19,  1.42it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
#  97%|█████████▋| 973/1000 [10:51<00:19,  1.39it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  98%|█████████▊| 977/1000 [10:53<00:14,  1.54it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  98%|█████████▊| 980/1000 [10:55<00:13,  1.54it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  98%|█████████▊| 981/1000 [10:56<00:12,  1.55it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  98%|█████████▊| 982/1000 [10:57<00:11,  1.55it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  99%|█████████▊| 987/1000 [11:00<00:08,  1.47it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  99%|█████████▉| 989/1000 [11:02<00:07,  1.45it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
#  99%|█████████▉| 990/1000 [11:02<00:07,  1.42it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 100%|█████████▉| 995/1000 [11:06<00:03,  1.44it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 100%|█████████▉| 997/1000 [11:07<00:02,  1.46it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 100%|█████████▉| 998/1000 [11:08<00:01,  1.56it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 100%|█████████▉| 999/1000 [11:08<00:00,  1.57it/s]/usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 100%|██████████| 1000/1000 [11:09<00:00,  1.49it/s]

# %%
print('BASELINE_best_MBR_CHRF:',np.mean(BASELINE_best_MBR_CHRF)+50)
print('BASELINE_best_MBR_CHRF_rank:',np.mean(BASELINE_best_MBR_CHRF_rank))
print('BASELINE_best_CHRF:',np.mean(BASELINE_best_CHRF)+50)

print('MODEL_best_MBR_CHRF:',np.mean(MODEL_best_MBR_CHRF)+50)
print('MODEL_best_MBR_CHRF_rank:',np.mean(MODEL_best_MBR_CHRF_rank))
print('MODEL_best_CHRF:',np.mean(MODEL_best_CHRF)+50)

print('UPPER_BOUND MBR CHRF:', MBR_CHRF_cand_scores[idx][MBR_CHRF_winner_index[idx]]+50)
print('UPPER_BOUND RANK:', MBR_CHRF_index_rank[idx][MBR_CHRF_winner_index[idx]])
print('UPPER_BOUND CHRF:', CHRF_cand_scores[idx][MBR_CHRF_winner_index[idx]]+50)
# Out:
# BASELINE_best_MBR_CHRF: 56.173231748501564
# BASELINE_best_MBR_CHRF_rank: 117.121
# BASELINE_best_CHRF: 44.682169319799996
# MODEL_best_MBR_CHRF: 56.59377978654297
# MODEL_best_MBR_CHRF_rank: 119.27465
# MODEL_best_CHRF: 44.9266645146
# UPPER_BOUND MBR CHRF: 62.966183171875
# UPPER_BOUND RANK: 128.0
# UPPER_BOUND CHRF: 36.169708

# %%
n = len(BASELINE_best_MBR_CHRF_rank)
print(n)
print('Baseline is Better', sum([BASELINE_best_MBR_CHRF_rank[i] > MODEL_best_MBR_CHRF_rank[i] for i in range(n)]))
print('Model is Better', sum([BASELINE_best_MBR_CHRF_rank[i] < MODEL_best_MBR_CHRF_rank[i] for i in range(n)]))
print('Tie', sum([BASELINE_best_MBR_CHRF_rank[i] == MODEL_best_MBR_CHRF_rank[i] for i in range(n)]))
# Out:
# 10000
# Baseline is Better 3795
# Model is Better 5179
# Tie 1026
